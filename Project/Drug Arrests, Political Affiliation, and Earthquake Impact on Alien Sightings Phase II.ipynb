# %% [markdown]
# # FINAL PROJECT PHASE II
# by Reed Walker, Harrison Melton

# %%
import csv
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Downloaded Dataset Requirement

# %%
'''
Source: https://www.ngdc.noaa.gov/hazard/eq-intensity.shtml
This data set is a replacement for our old dataset about political affiliation.
It is a dataset of earthquakes.
We are looking to see if there is a relationship between ufo sightings and earthquakes in the area.
Size: 157,016 rows, 18 columns, 12.4MB
'''

def data_parser():
    data = pd.read_excel('equake.xlsx')
    
    # CLEAN - drop all the unneccessary columns
    data.drop(['HOUR','MINUTE','SECOND','LOCAL_TO_UTC','UNPUB_OR_GROUPED_INT','LATITUDE','LONGITUDE','EQ_DEPTH','EPIDIST','CITY_LAT','CITY_LON','MMI','SOURCE'], inplace=True, axis=1)
    
    # CLEAN - drop null values
    data.dropna(inplace=True)

    # CLEAN - sort the values by state then, year
    data.sort_values(by = ["STATE","YEAR"], inplace=True)
    
    # CLEAN - annex Canada
    data = data[data.COUNTRY != "CANADA"]

    # export to csv
    data.to_csv('qr1.csv', index=False)
    
    return data

############ Function Call ############
data_parser()
# Out:
#         YEAR  MONTH   DAY  MAGNITUDE STATE              CITY COUNTRY
# 3759    1899    9.0  10.0        7.8    AK     CAPE YAKATAGA     USA
# 4035    1899    9.0  10.0        8.6    AK       YAKUTAT BAY     USA
# 4036    1899    9.0  10.0        8.6    AK           SKAGWAY     USA
# 4037    1899    9.0  10.0        8.6    AK      BARTLETT BAY     USA
# 4038    1899    9.0  10.0        8.6    AK        DUNDAS BAY     USA
# ...      ...    ...   ...        ...   ...               ...     ...
# 135006  1985   11.0  17.0        3.5    WY      OLD FAITHFUL     USA
# 135007  1985   11.0  17.0        3.1    WY      OLD FAITHFUL     USA
# 135008  1985   11.0  19.0        2.8    WY  MADISON JUNCTION     USA
# 135016  1985   11.0  20.0        3.1    WY  MADISON JUNCTION     USA
# 135019  1985   11.0  22.0        3.5    WY      OLD FAITHFUL     USA
#
# [108963 rows x 7 columns]

# %% [markdown]
# ## Web Collection Requirement \#1

# %%
def api_parser():
    
    # 1 - Base URL
    url = 'https://api.usa.gov/crime/fbi/sapi/' # source

    # 2 - Request Parameters
    offense = 'drug-grand-total'
    variable = 'monthly'
    since = '2000'
    until = '2019'

    # 3 - API Key
    key = r'?API_KEY=gw18Vys2MaENl190DI6O0I6bKYW0IaujhZK4bHYE'

    state_dict = {}
    with open('state_data.json', 'r') as state_data:
        state_dict = json.load(state_data)

    for state in state_dict.keys():
        endpoint = f'api/data/arrest/states/{state}/{offense}/{variable}/{since}/{until}'
        r = requests.get(url + endpoint + key)
        rlist = r.json()['results'] # each item(dict) corresponds to a year
        for year in rlist:
            state_dict[state].update({year['data_year']: (year['male_count'] + year['female_count'])})
            
    
    # 4 - CLEAN: remove florida, because it's florida... also so many missing values
    state_dict.pop('FL')    
    
    with open('drug_data.json', 'w') as drug_data:
        json.dump(state_dict, drug_data, indent=4)

    return state_dict

############ Function Call ############
api_parser()
# Out:
# {'AL': {2000: 12292,
#   2001: 12932,
#   2002: 14100,
#   2003: 16133,
#   2004: 18315,
#   2005: 15704,
#   2006: 14860,
#   2007: 17309,
#   2008: 16488,
#   2009: 15180,
#   2010: 8213,
#   2011: 300,
#   2012: 306,
#   2013: 325,
#   2014: 220,
#   2015: 9411,
#   2016: 10327,
#   2017: 10541,
#   2018: 10349,
#   2019: 378},
#  'AK': {2000: 1763,
#   2001: 1592,
#   2002: 1643,
#   2003: 2132,
#   2004: 1755,
#   2005: 1885,
#   2006: 1701,
#   2007: 1759,
#   2008: 1725,
#   2009: 2060,
#   2010: 2493,
#   2011: 2349,
#   2012: 1547,
#   2013: 1475,
#   2014: 1159,
#   2015: 1212,
#   2016: 1006,
#   2017: 1004,
#   2018: 1046,
#   2019: 930},
#  'AZ': {2000: 28613,
#   2001: 30167,
#   2002: 29278,
#   2003: 32908,
#   2004: 36502,
#   2005: 36571,
#   2006: 36498,
#   2007: 36252,
#   2008: 35382,
#   2009: 35270,
#   2010: 31533,
#   2011: 30992,
#   2012: 28686,
#   2013: 31041,
#   2014: 30222,
#   2015: 25333,
#   2016: 31044,
#   2017: 35728,
#   2018: 33306,
#   2019: 30825},
#  'AR': {2000: 13809,
#   2001: 11500,
#   2002: 9054,
#   2003: 12047,
#   2004: 12838,
#   2005: 14848,
#   2006: 15392,
#   2007: 10698,
#   2008: 12047,
#   2009: 12312,
#   2010: 12970,
#   2011: 11067,
#   2012: 11462,
#   2013: 11477,
#   2014: 11534,
#   2015: 12900,
#   2016: 16027,
#   2017: 17862,
#   2018: 19329,
#   2019: 18132},
#  'CA': {2000: 251448,
#   2001: 248443,
#   2002: 255778,
#   2003: 273226,
#   2004: 272980,
#   2005: 305745,
#   2006: 301406,
#   2007: 289449,
#   2008: 268763,
#   2009: 251187,
#   2010: 248560,
#   2011: 188188,
#   2012: 199755,
#   2013: 217520,
#   2014: 229083,
#   2015: 206835,
#   2016: 219016,
#   2017: 212977,
#   2018: 219251,
#   2019: 218674},
#  'CO': {2000: 16683,
#   2001: 18021,
#   2002: 16159,
#   2003: 16451,
#   2004: 19275,
#   2005: 20387,
#   2006: 19843,
#   2007: 19361,
#   2008: 18757,
#   2009: 17439,
#   2010: 16574,
#   2011: 16293,
#   2012: 16665,
#   2013: 12380,
#   2014: 13404,
#   2015: 14678,
#   2016: 15558,
#   2017: 16970,
#   2018: 18126,
#   2019: 16146},
#  'CT': {2000: 16392,
#   2001: 21030,
#   2002: 16288,
#   2003: 13985,
#   2004: 16224,
#   2005: 15105,
#   2006: 15648,
#   2007: 15579,
#   2008: 18528,
#   2009: 17750,
#   2010: 17794,
#   2011: 14070,
#   2012: 9710,
#   2013: 9186,
#   2014: 10073,
#   2015: 8419,
#   2016: 10214,
#   2017: 9243,
#   2018: 8379,
#   2019: 7403},
#  'DE': {2000: 3949,
#   2001: 2835,
#   2002: 3208,
#   2003: 4483,
#   2004: 4264,
#   2005: 5441,
#   2006: 5807,
#   2007: 5919,
#   2008: 5943,
#   2009: 5770,
#   2010: 5429,
#   2011: 5195,
#   2012: 5505,
#   2013: 6332,
#   2014: 6178,
#   2015: 5773,
#   2016: 4299,
#   2017: 4041,
#   2018: 3711,
#   2019: 3815},
#  'GA': {2000: 26585,
#   2001: 27353,
#   2002: 27315,
#   2003: 32942,
#   2004: 27640,
#   2005: 29540,
#   2006: 34221,
#   2007: 45948,
#   2008: 36460,
#   2009: 39965,
#   2010: 41634,
#   2011: 42814,
#   2012: 45897,
#   2013: 45104,
#   2014: 44588,
#   2015: 39912,
#   2016: 45015,
#   2017: 45869,
#   2018: 50337,
#   2019: 18209},
#  'HI': {2000: 2469,
#   2001: 3023,
#   2002: 3111,
#   2003: 3286,
#   2004: 3242,
#   2005: 3258,
#   2006: 3027,
#   2007: 3331,
#   2008: 2709,
#   2009: 2806,
#   2010: 2802,
#   2011: 2773,
#   2012: 2930,
#   2013: 1685,
#   2014: 1692,
#   2015: 2953,
#   2016: 3567,
#   2017: 2733,
#   2018: 2511,
#   2019: 1947},
#  'ID': {2000: 5363,
#   2001: 5189,
#   2002: 5532,
#   2003: 5610,
#   2004: 5865,
#   2005: 5492,
#   2006: 5816,
#   2007: 6008,
#   2008: 5729,
#   2009: 5877,
#   2010: 6571,
#   2011: 7064,
#   2012: 6892,
#   2013: 7623,
#   2014: 7435,
#   2015: 8301,
#   2016: 9428,
#   2017: 10971,
#   2018: 11908,
#   2019: 10889},
#  'IL': {2000: 58697,
#   2001: 57473,
#   2002: 54205,
#   2003: 55795,
#   2004: 59054,
#   2005: 58093,
#   2006: 57477,
#   2007: 55115,
#   2008: 45588,
#   2009: 43518,
#   2010: 42925,
#   2011: 38688,
#   2012: 35699,
#   2013: 34982,
#   2014: 29450,
#   2015: 24088,
#   2016: 12944,
#   2017: 10861,
#   2018: 17027,
#   2019: 569},
#  'IN': {2000: 16911,
#   2001: 17885,
#   2002: 18279,
#   2003: 20323,
#   2004: 22650,
#   2005: 24643,
#   2006: 19709,
#   2007: 22851,
#   2008: 23468,
#   2009: 23296,
#   2010: 17089,
#   2011: 23310,
#   2012: 18949,
#   2013: 73314,
#   2014: 16348,
#   2015: 17407,
#   2016: 19025,
#   2017: 24537,
#   2018: 27360,
#   2019: 20575},
#  'IA': {2000: 9423,
#   2001: 8578,
#   2002: 10230,
#   2003: 10368,
#   2004: 10161,
#   2005: 10173,
#   2006: 9742,
#   2007: 9278,
#   2008: 8561,
#   2009: 8596,
#   2010: 9435,
#   2011: 9433,
#   2012: 8915,
#   2013: 9439,
#   2014: 9244,
#   2015: 9150,
#   2016: 9850,
#   2017: 10513,
#   2018: 8632,
#   2019: 9032},
#  'KS': {2000: 6416,
#   2001: 6328,
#   2002: 6132,
#   2003: 8794,
#   2004: 8526,
#   2005: 7623,
#   2006: 6973,
#   2007: 7937,
#   2008: 7140,
#   2009: 6698,
#   2010: 8375,
#   2011: 7858,
#   2012: 8088,
#   2013: 8262,
#   2014: 7774,
#   2015: 8203,
#   2016: 8627,
#   2017: 9930,
#   2018: 2507,
#   2019: 9470},
#  'KY': {2000: 2086,
#   2001: 8566,
#   2002: 10895,
#   2003: 4637,
#   2004: 17516,
#   2005: 43033,
#   2006: 21506,
#   2007: 23485,
#   2008: 16803,
#   2009: 29359,
#   2010: 19642,
#   2011: 21922,
#   2012: 21590,
#   2013: 22444,
#   2014: 22081,
#   2015: 22796,
#   2016: 23621,
#   2017: 27537,
#   2018: 28459,
#   2019: 25222},
#  'LA': {2000: 21402,
#   2001: 22342,
#   2002: 21967,
#   2003: 23602,
#   2004: 26521,
#   2005: 23482,
#   2006: 24004,
#   2007: 23776,
#   2008: 18376,
#   2009: 19459,
#   2010: 19331,
#   2011: 14934,
#   2012: 19340,
#   2013: 20835,
#   2014: 18241,
#   2015: 27277,
#   2016: 29930,
#   2017: 24536,
#   2018: 33935,
#   2019: 27364},
#  'ME': {2000: 5064,
#   2001: 4948,
#   2002: 4861,
#   2003: 5153,
#   2004: 5731,
#   2005: 4737,
#   2006: 5933,
#   2007: 5924,
#   2008: 5380,
#   2009: 5923,
#   2010: 5933,
#   2011: 5710,
#   2012: 5559,
#   2013: 5608,
#   2014: 5802,
#   2015: 5946,
#   2016: 5516,
#   2017: 3330,
#   2018: 3838,
#   2019: 3616},
#  'MD': {2000: 41500,
#   2001: 52579,
#   2002: 51538,
#   2003: 54531,
#   2004: 51957,
#   2005: 52472,
#   2006: 55469,
#   2007: 55379,
#   2008: 57288,
#   2009: 51275,
#   2010: 47410,
#   2011: 43249,
#   2012: 41047,
#   2013: 34007,
#   2014: 39713,
#   2015: 26681,
#   2016: 32951,
#   2017: 30995,
#   2018: 33921,
#   2019: 30576},
#  'MA': {2000: 17006,
#   2001: 17887,
#   2002: 16716,
#   2003: 10471,
#   2004: 12663,
#   2005: 15264,
#   2006: 18804,
#   2007: 21538,
#   2008: 21271,
#   2009: 12544,
#   2010: 12385,
#   2011: 11178,
#   2012: 12001,
#   2013: 11241,
#   2014: 11004,
#   2015: 10237,
#   2016: 10537,
#   2017: 9864,
#   2018: 8728,
#   2019: 8334},
#  'MI': {2000: 35721,
#   2001: 37150,
#   2002: 36621,
#   2003: 33537,
#   2004: 31732,
#   2005: 33731,
#   2006: 35717,
#   2007: 34591,
#   2008: 34007,
#   2009: 35230,
#   2010: 35220,
#   2011: 32920,
#   2012: 32926,
#   2013: 34564,
#   2014: 34637,
#   2015: 36007,
#   2016: 39256,
#   2017: 33507,
#   2018: 30598,
#   2019: 13572},
#  'MN': {2000: 22268,
#   2001: 10518,
#   2002: 13387,
#   2003: 13040,
#   2004: 14939,
#   2005: 24684,
#   2006: 18235,
#   2007: 18864,
#   2008: 18360,
#   2009: 17182,
#   2010: 17837,
#   2011: 19678,
#   2012: 23151,
#   2013: 21492,
#   2014: 21491,
#   2015: 20042,
#   2016: 18248,
#   2017: 23519,
#   2018: 22296,
#   2019: 20452},
#  'MS': {2000: 11472,
#   2001: 9521,
#   2002: 12366,
#   2003: 10810,
#   2004: 15471,
#   2005: 16319,
#   2006: 16778,
#   2007: 10750,
#   2008: 13696,
#   2009: 13507,
#   2010: 11266,
#   2011: 10856,
#   2012: 11236,
#   2013: 8752,
#   2014: 10002,
#   2015: 10901,
#   2016: 11895,
#   2017: 12493,
#   2018: 9420,
#   2019: 9472},
#  'MO': {2000: 22343,
#   2001: 32389,
#   2002: 34797,
#   2003: 42129,
#   2004: 35575,
#   2005: 42103,
#   2006: 44900,
#   2007: 38503,
#   2008: 36344,
#   2009: 36671,
#   2010: 34411,
#   2011: 35411,
#   2012: 35026,
#   2013: 35438,
#   2014: 33503,
#   2015: 34286,
#   2016: 41959,
#   2017: 42077,
#   2018: 35222,
#   2019: 31744},
#  'MT': {2000: 509,
#   2001: 442,
#   2002: 725,
#   2003: 664,
#   2005: 1811,
#   2006: 1808,
#   2007: 1812,
#   2008: 1632,
#   2009: 1571,
#   2010: 1701,
#   2011: 1840,
#   2012: 2159,
#   2013: 2034,
#   2014: 2209,
#   2015: 2377,
#   2016: 2651,
#   2017: 2926,
#   2018: 2855,
#   2019: 2661},
#  'NE': {2000: 10086,
#   2001: 10978,
#   2002: 11860,
#   2003: 10187,
#   2004: 10876,
#   2005: 11224,
#   2006: 10414,
#   2007: 10200,
#   2008: 10601,
#   2009: 9806,
#   2010: 10195,
#   2011: 10479,
#   2012: 10657,
#   2013: 10698,
#   2014: 11995,
#   2015: 8753,
#   2016: 12546,
#   2017: 5379,
#   2018: 11754,
#   2019: 11698},
#  'NV': {2000: 10120,
#   2001: 9901,
#   2002: 9473,
#   2003: 8959,
#   2004: 9832,
#   2005: 11890,
#   2006: 13784,
#   2007: 14518,
#   2008: 14886,
#   2009: 17240,
#   2010: 16268,
#   2011: 15562,
#   2012: 15537,
#   2013: 11207,
#   2014: 12508,
#   2015: 11594,
#   2016: 13770,
#   2017: 22220,
#   2018: 11249,
#   2019: 12701},
#  'NH': {2000: 3479,
#   2001: 3512,
#   2002: 4688,
#   2003: 2227,
#   2004: 3600,
#   2005: 3261,
#   2006: 3398,
#   2007: 2878,
#   2008: 3552,
#   2009: 4056,
#   2010: 4127,
#   2011: 4066,
#   2012: 4014,
#   2013: 4350,
#   2014: 6485,
#   2015: 7831,
#   2016: 8505,
#   2017: 7981,
#   2018: 6668,
#   2019: 5584},
#  'NJ': {2000: 55527,
#   2001: 52260,
#   2002: 54560,
#   2003: 51716,
#   2004: 53338,
#   2005: 53846,
#   2006: 54194,
#   2007: 52773,
#   2008: 52749,
#   2009: 52470,
#   2010: 49072,
#   2011: 46377,
#   2012: 51297,
#   2013: 51440,
#   2014: 53458,
#   2015: 49499,
#   2016: 62247,
#   2017: 63725,
#   2018: 56466,
#   2019: 55951},
#  'NM': {2000: 4649,
#   2001: 3865,
#   2002: 4389,
#   2003: 5559,
#   2004: 7429,
#   2005: 6683,
#   2006: 5775,
#   2007: 6868,
#   2008: 6542,
#   2009: 7223,
#   2010: 8818,
#   2011: 8877,
#   2012: 8117,
#   2013: 6244,
#   2014: 5529,
#   2015: 7796,
#   2016: 8254,
#   2017: 2690,
#   2018: 5667,
#   2019: 3323},
#  'NY': {2000: 182527,
#   2001: 155341,
#   2002: 50096,
#   2003: 44135,
#   2004: 52795,
#   2005: 57225,
#   2006: 61748,
#   2007: 61163,
#   2008: 52945,
#   2009: 60460,
#   2010: 62519,
#   2011: 56520,
#   2012: 65840,
#   2013: 64052,
#   2014: 62627,
#   2015: 60534,
#   2016: 65878,
#   2017: 71263,
#   2018: 70575,
#   2019: 55751},
#  'NC': {2000: 34110,
#   2001: 37849,
#   2002: 35275,
#   2003: 39583,
#   2004: 31695,
#   2005: 38687,
#   2006: 34969,
#   2007: 38343,
#   2008: 36571,
#   2009: 33062,
#   2010: 33170,
#   2011: 42225,
#   2012: 40869,
#   2013: 35487,
#   2014: 34695,
#   2015: 23361,
#   2016: 24600,
#   2017: 30363,
#   2018: 37926,
#   2019: 31605},
#  'ND': {2000: 1361,
#   2001: 1387,
#   2002: 1375,
#   2003: 1659,
#   2004: 1633,
#   2005: 2017,
#   2006: 1919,
#   2007: 1879,
#   2008: 1836,
#   2009: 1906,
#   2010: 2005,
#   2011: 2364,
#   2012: 2859,
#   2013: 3389,
#   2014: 4024,
#   2015: 4664,
#   2016: 5734,
#   2017: 5678,
#   2018: 5467,
#   2019: 5005},
#  'OH': {2000: 24835,
#   2001: 25382,
#   2002: 22726,
#   2003: 27300,
#   2004: 34525,
#   2005: 36240,
#   2006: 37019,
#   2007: 38242,
#   2008: 35770,
#   2009: 35136,
#   2010: 32816,
#   2011: 30471,
#   2012: 30411,
#   2013: 30505,
#   2014: 37451,
#   2015: 34940,
#   2016: 39778,
#   2017: 41808,
#   2018: 43233,
#   2019: 33695},
#  'OK': {2000: 21952,
#   2001: 20400,
#   2002: 21773,
#   2003: 23013,
#   2004: 21840,
#   2005: 21468,
#   2006: 20823,
#   2007: 22321,
#   2008: 21151,
#   2009: 20484,
#   2010: 19994,
#   2011: 17353,
#   2012: 17190,
#   2013: 17173,
#   2014: 18192,
#   2015: 18473,
#   2016: 23364,
#   2017: 21112,
#   2018: 18923,
#   2019: 16468},
#  'OR': {2000: 16544,
#   2001: 16092,
#   2002: 13487,
#   2003: 16797,
#   2004: 23434,
#   2005: 23200,
#   2006: 20848,
#   2007: 19170,
#   2008: 17344,
#   2009: 16078,
#   2010: 17459,
#   2011: 19678,
#   2012: 20108,
#   2013: 10915,
#   2014: 14060,
#   2015: 12557,
#   2016: 15621,
#   2017: 16054,
#   2018: 15581,
#   2019: 14124},
#  'PA': {2000: 43160,
#   2001: 47917,
#   2002: 49755,
#   2003: 47438,
#   2004: 52322,
#   2005: 53322,
#   2006: 56115,
#   2007: 57882,
#   2008: 56744,
#   2009: 53638,
#   2010: 56456,
#   2011: 55260,
#   2012: 57300,
#   2013: 57928,
#   2014: 58455,
#   2015: 56646,
#   2016: 57543,
#   2017: 63842,
#   2018: 62898,
#   2019: 19398},
#  'RI': {2000: 3988,
#   2001: 4381,
#   2002: 4077,
#   2003: 4621,
#   2004: 6544,
#   2005: 2915,
#   2006: 4090,
#   2007: 3502,
#   2008: 3794,
#   2009: 4265,
#   2010: 3809,
#   2011: 3588,
#   2012: 3664,
#   2013: 2242,
#   2014: 1917,
#   2015: 1761,
#   2016: 1762,
#   2017: 1985,
#   2018: 2049,
#   2019: 1866},
#  'SC': {2000: 25228,
#   2001: 20633,
#   2002: 25429,
#   2003: 28478,
#   2004: 28876,
#   2005: 31492,
#   2006: 32799,
#   2007: 32107,
#   2008: 18740,
#   2009: 28792,
#   2010: 30984,
#   2011: 28083,
#   2012: 29387,
#   2013: 29287,
#   2014: 29939,
#   2015: 28694,
#   2016: 31925,
#   2017: 36017,
#   2018: 38069,
#   2019: 33128},
#  'SD': {2000: 2982,
#   2001: 2345,
#   2002: 2770,
#   2003: 2862,
#   2004: 1855,
#   2005: 1440,
#   2006: 1546,
#   2007: 2003,
#   2008: 2503,
#   2009: 3205,
#   2010: 3209,
#   2011: 3802,
#   2012: 4397,
#   2013: 5382,
#   2014: 5528,
#   2015: 7081,
#   2016: 8080,
#   2017: 8926,
#   2018: 8144,
#   2019: 8001},
#  'TN': {2000: 22448,
#   2001: 23661,
#   2002: 23639,
#   2003: 32634,
#   2004: 36216,
#   2005: 39363,
#   2006: 39048,
#   2007: 43754,
#   2008: 39493,
#   2009: 41436,
#   2010: 42697,
#   2011: 42873,
#   2012: 45733,
#   2013: 47188,
#   2014: 42168,
#   2015: 39832,
#   2016: 46276,
#   2017: 49319,
#   2018: 50573,
#   2019: 46748},
#  'TX': {2000: 107182,
#   2001: 104539,
#   2002: 103424,
#   2003: 109828,
#   2004: 129233,
#   2005: 124749,
#   2006: 137401,
#   2007: 145627,
#   2008: 142813,
#   2009: 146197,
#   2010: 137382,
#   2011: 133133,
#   2012: 138113,
#   2013: 135277,
#   2014: 140179,
#   2015: 133711,
#   2016: 145246,
#   2017: 147754,
#   2018: 149526,
#   2019: 123579},
#  'UT': {2000: 8177,
#   2001: 10141,
#   2002: 9088,
#   2003: 9197,
#   2004: 9208,
#   2005: 9385,
#   2006: 9382,
#   2007: 10552,
#   2008: 10452,
#   2009: 11348,
#   2010: 10932,
#   2011: 10953,
#   2012: 12827,
#   2013: 13768,
#   2014: 14750,
#   2015: 15798,
#   2016: 16193,
#   2017: 19918,
#   2018: 20489,
#   2019: 17064},
#  'VT': {2000: 1137,
#   2001: 1403,
#   2002: 1568,
#   2003: 1482,
#   2004: 1581,
#   2005: 1536,
#   2006: 1887,
#   2007: 1635,
#   2008: 1418,
#   2009: 1436,
#   2010: 1351,
#   2011: 1354,
#   2012: 1586,
#   2013: 1326,
#   2014: 696,
#   2015: 684,
#   2016: 842,
#   2017: 1230,
#   2018: 919,
#   2019: 927},
#  'VA': {2000: 23555,
#   2001: 24740,
#   2002: 25393,
#   2003: 26447,
#   2004: 28060,
#   2005: 30477,
#   2006: 32155,
#   2007: 35360,
#   2008: 33517,
#   2009: 33004,
#   2010: 34513,
#   2011: 36538,
#   2012: 38741,
#   2013: 40668,
#   2014: 37784,
#   2015: 37046,
#   2016: 39905,
#   2017: 45423,
#   2018: 47352,
#   2019: 43933},
#  'WA': {2000: 24075,
#   2001: 24923,
#   2002: 26075,
#   2003: 24805,
#   2004: 24956,
#   2005: 26344,
#   2006: 30846,
#   2007: 29469,
#   2008: 24998,
#   2009: 18587,
#   2010: 24036,
#   2011: 17837,
#   2012: 14986,
#   2013: 11809,
#   2014: 12236,
#   2015: 12990,
#   2016: 11372,
#   2017: 12198,
#   2018: 11883,
#   2019: 11996},
#  'WV': {2000: 3339,
#   2001: 2555,
#   2002: 2452,
#   2003: 3044,
#   2004: 4781,
#   2005: 5950,
#   2006: 7042,
#   2007: 4673,
#   2008: 6934,
#   2009: 7594,
#   2010: 6628,
#   2011: 6877,
#   2012: 8111,
#   2013: 6913,
#   2014: 6425,
#   2015: 7147,
#   2016: 7317,
#   2017: 8453,
#   2018: 7131,
#   2019: 5058},
#  'WI': {2001: 5614,
#   2002: 24420,
#   2003: 29970,
#   2004: 17353,
#   2005: 20612,
#   2006: 26551,
#   2007: 26933,
#   2008: 25864,
#   2009: 24622,
#   2010: 23057,
#   2011: 24509,
#   2012: 26780,
#   2013: 25976,
#   2014: 25172,
#   2015: 25481,
#   2016: 29105,
#   2017: 31539,
#   2018: 31362,
#   2019: 26713},
#  'WY': {2000: 2310,
#   2001: 2719,
#   2002: 2730,
#   2003: 2579,
#   2004: 3044,
#   2005: 3283,
#   2006: 3160,
#   2007: 3116,
#   2008: 2969,
#   2009: 2807,
#   2010: 3103,
#   2011: 3205,
#   2012: 3036,
#   2013: 3527,
#   2014: 3459,
#   2015: 3899,
#   2016: 4498,
#   2017: 4617,
#   2018: 4859,
#   2019: 4611}}

# %% [markdown]
# ## Web Collection Requirement \#2

# %%
def html_parser():
    
    ufo_dict = {}
    with open('state_data.json', 'r') as state_data:
        ufo_dict = json.load(state_data)
        
    for key in ufo_dict.keys():
        ufo_dict[key] = []
    
    for state_abbr in ufo_dict.keys():
        url = f'http://www.nuforc.org/webreports/ndxl{state_abbr}.html' # source
        r = requests.get(url)
        soup = BeautifulSoup(r.text, 'html.parser')
        table = soup.find_all("tr")

        for post in table[1:]:
            # collect attributes
            row = post.find_all("td")

            # ITS CLEANING TIME
            clean = True

            # these are fine I guess
            city = row[1].text.strip()
            state = row[2].text.strip()
            summary = row[5].text.strip()
            posted = row[6].text.strip()

            # these are not
            time = row[0].text.strip()  # split the time into date and time
            time = tuple(time.split())
            if len(time) < 2:
                clean = False 

            shape = row[3].text.strip()  # check to see if the shape is known
            if shape.lower() == "unknown":
                clean = False

            duration = row[4].text.strip()
            if not any(map(str.isdigit, duration)):  # check to see if duration contains a number
                clean = False

            # add if values are non-null and clean
            if (bool(time) * bool(city) * bool(state) * bool(shape) * bool(duration) * bool(summary) * bool(posted) * clean):
                ufo_dict[state_abbr].append((time, city, shape))

    
    with open('ufo_data.json', 'w') as ufo_data:
        json.dump(ufo_dict, ufo_data, indent=4)

    return ufo_dict

############ Function Call ############
html_parser()
# Out:
# {'AL': [(('5/16/21', '09:54'), 'Vincent', 'Light'),
#   (('5/9/21', '23:30'), 'Mobile', 'Circle'),
#   (('4/27/21', '10:22'), 'Gulf Shores', 'Sphere'),
#   (('4/11/21', '20:35'), 'Altoona', 'Other'),
#   (('3/5/21', '23:00'), 'Bessemer', 'Triangle'),
#   (('2/20/21', '10:15'), 'Fort Payne', 'Cylinder'),
#   (('2/13/21', '19:53'), 'Citronelle', 'Other'),
#   (('2/9/21', '19:30'), 'Silas', 'Sphere'),
#   (('12/26/20', '18:20'), 'Decatur', 'Light'),
#   (('12/1/20', '17:50'), 'Birmingham', 'Light'),
#   (('11/30/20', '00:40'), 'Huntsville', 'Light'),
#   (('10/16/20', '21:35'), 'Billingsley', 'Circle'),
#   (('10/13/20', '20:30'), 'robertsdale', 'Changing'),
#   (('10/8/20', '05:20'), 'Baileyton', 'Light'),
#   (('10/1/20', '05:00'), 'Moundville', 'Changing'),
#   (('9/28/20', '15:00'), 'Athens', 'Other'),
#   (('9/26/20', '00:34'), 'Huntsville', 'Light'),
#   (('9/11/20', '20:20'), 'Huntsville', 'Light'),
#   (('9/4/20', '21:30'), 'Gulf Shores', 'Light'),
#   (('8/19/20', '22:00'), 'Fort Morgan', 'Circle'),
#   (('8/19/20', '16:15'), 'Huntsville', 'Light'),
#   (('8/18/20', '22:00'), 'Gulf Shores', 'Cylinder'),
#   (('8/14/20', '13:30'), 'Mobile', 'Rectangle'),
#   (('8/2/20', '01:45'), 'Satsuma', 'Circle'),
#   (('8/1/20', '22:50'), 'Madison', 'Light'),
#   (('7/31/20', '23:00'), 'Spanish Fort', 'Changing'),
#   (('7/26/20', '19:45'), 'Birmingham', 'Light'),
#   (('7/21/20', '08:45'), 'Axis', 'Oval'),
#   (('7/10/20', '22:00'), 'Deatsville', 'Circle'),
#   (('7/4/20', '21:30'), 'Anniston', 'Circle'),
#   (('7/4/20', '20:00'), 'Huntsville', 'Circle'),
#   (('7/2/20', '21:30'), 'Fort Payne', 'Circle'),
#   (('6/18/20', '03:00'), 'Oneonta', 'Circle'),
#   (('6/11/20', '12:00'), 'Altoona', 'Other'),
#   (('6/10/20', '19:00'), 'Enterprise', 'Disk'),
#   (('5/25/20', '21:00'), 'Trussville', 'Triangle'),
#   (('5/13/20', '23:50'), 'Pike rd', 'Cylinder'),
#   (('4/30/20', '22:00'), 'Lincoln', 'Other'),
#   (('4/25/20', '10:30'), 'Anniston', 'Circle'),
#   (('4/20/20', '11:15'), 'Enterprise', 'Sphere'),
#   (('4/13/20', '21:15'), 'Phenix City', 'Light'),
#   (('4/11/20', '21:05'), 'Hanceville', 'Light'),
#   (('4/10/20', '00:00'), 'Boaz', 'Other'),
#   (('4/9/20', '05:00'), 'Prattville', 'Sphere'),
#   (('4/7/20', '18:00'), 'Warrior', 'Egg'),
#   (('3/29/20', '11:00'), 'Citronelle', 'Circle'),
#   (('2/19/20', '15:50'), 'Hoover', 'Triangle'),
#   (('2/2/20', '19:00'), 'Chelsea', 'Oval'),
#   (('2/2/20', '15:30'), 'Ross Bridge', 'Formation'),
#   (('2/2/20', '07:30'), 'Hueytown', 'Other'),
#   (('2/1/20', '07:00'), 'Southside', 'Light'),
#   (('1/15/20', '22:00'), 'Irvington', 'Sphere'),
#   (('1/8/20', '18:00'), 'Littleville', 'Light'),
#   (('1/6/20', '16:25'), 'Saraland/Mobile', 'Disk'),
#   (('12/30/19', '22:20'), 'Madison', 'Triangle'),
#   (('12/30/19', '12:00'), 'Birmingham', 'Disk'),
#   (('12/27/19', '19:00'), 'Elkmont', 'Fireball'),
#   (('12/25/19', '17:40'), 'Madison', 'Triangle'),
#   (('12/19/19', '17:39'), 'Hartselle', 'Light'),
#   (('12/18/19', '08:30'), 'Rock Ledge', 'Disk'),
#   (('12/11/19', '19:25'), 'Coosada', 'Cigar'),
#   (('11/30/19', '04:45'), 'Woodstock', 'Fireball'),
#   (('11/21/19', '18:05'), 'Daphne', 'Light'),
#   (('11/19/19', '19:30'), 'Mobile', 'Light'),
#   (('11/10/19', '17:00'), 'Silverhilll', 'Sphere'),
#   (('11/10/19', '16:26'), 'Mobile', 'Circle'),
#   (('10/24/19', '23:00'), 'Gurley', 'Circle'),
#   (('10/19/19', '20:00'), 'Melbourne', 'Light'),
#   (('10/11/19', '20:00'), 'Phenix City', 'Cigar'),
#   (('10/10/19', '17:00'), 'Fowl River', 'Circle'),
#   (('10/6/19', '03:00'), 'Fairhope', 'Triangle'),
#   (('10/1/19', '19:00'), 'Elberta', 'Circle'),
#   (('9/29/19', '20:00'), 'Brierfield', 'Other'),
#   (('9/28/19', '09:30'), 'Lincoln', 'Other'),
#   (('9/25/19', '08:45'), 'Brantley', 'Cylinder'),
#   (('9/24/19', '21:30'), 'Mobile', 'Fireball'),
#   (('9/18/19', '18:40'), 'Florence', 'Light'),
#   (('8/16/19', '08:00'), 'Clanton', 'Cigar'),
#   (('8/5/19', '16:00'), 'Birmingham', 'Circle'),
#   (('8/4/19', '22:00'), 'Samson', 'Sphere'),
#   (('7/20/19', '22:00'), 'Boaz', 'Light'),
#   (('7/17/19', '04:05'), 'Coker', 'Other'),
#   (('7/8/19', '22:24'), 'Huntsville', 'Light'),
#   (('7/4/19', '21:00'), 'Gadsden', 'Triangle'),
#   (('7/4/19', '21:00'), 'Homewood', 'Triangle'),
#   (('6/30/19', '01:30'), 'Clay', 'Fireball'),
#   (('6/15/19', '21:11'), 'Madison', 'Rectangle'),
#   (('6/13/19', '20:45'), 'Gadsden', 'Light'),
#   (('5/26/19', '00:00'), 'Grants', 'Formation'),
#   (('5/24/19', '00:14'), 'Hazel green', 'Light'),
#   (('5/21/19', '22:00'), 'Decatur', 'Triangle'),
#   (('5/20/19', '23:00'), 'Gulf Shores', 'Triangle'),
#   (('5/8/19', '18:00'), 'Clanton', 'Rectangle'),
#   (('5/6/19', '01:00'), 'Delta', 'Triangle'),
#   (('4/26/19', '22:00'), 'Orange Beach', 'Sphere'),
#   (('4/21/19', '21:15'), 'Dauphin Island', 'Other'),
#   (('4/4/19', '05:55'), 'Huntsville', 'Circle'),
#   (('3/30/19', '23:00'), 'Gulf Shores', 'Sphere'),
#   (('3/22/19', '20:05'), 'Jacksonville', 'Triangle'),
#   (('2/25/19', '23:45'), 'McKenzie', 'Triangle'),
#   (('1/15/19', '01:20'), 'Orange Beach', 'Fireball'),
#   (('11/18/18', '18:00'), 'Cullman', 'Rectangle'),
#   (('10/31/18', '20:00'), 'Somerville', 'Fireball'),
#   (('10/18/18', '22:00'), 'Muscadine', 'Triangle'),
#   (('10/18/18', '21:00'), 'Ranburne', 'Light'),
#   (('9/30/18', '23:30'), 'Elkmomt', 'Light'),
#   (('9/13/18', '23:32'), 'Helena', 'Light'),
#   (('8/14/18', '23:00'), 'Hartselle', 'Changing'),
#   (('7/29/18', '17:15'), 'Huntsville', 'Chevron'),
#   (('7/22/18', '18:00'), 'Brookwood', 'Triangle'),
#   (('7/20/18', '21:00'), 'Owens Cross Roads', 'Light'),
#   (('7/19/18', '10:30'), 'Foley', 'Other'),
#   (('7/18/18', '22:00'), 'Tuscaloosa', 'Fireball'),
#   (('7/18/18', '21:30'), 'Vance', 'Light'),
#   (('7/17/18', '22:40'), 'Vance', 'Chevron'),
#   (('7/16/18', '23:00'), 'Trinity', 'Light'),
#   (('6/25/18', '20:15'), 'Dauphin Island', 'Changing'),
#   (('6/21/18', '04:30'), 'Ranburne', 'Sphere'),
#   (('5/31/18', '22:10'), 'Vestavia Hills', 'Other'),
#   (('4/4/18', '21:00'), 'Fort Payne', 'Rectangle'),
#   (('3/22/18', '07:18'), 'Pelham', 'Egg'),
#   (('3/4/18', '20:45'), 'Irvington', 'Circle'),
#   (('2/21/18', '21:37'), 'Pineywoods/Sipsey area', 'Light'),
#   (('12/26/17', '20:30'), 'Huntsville', 'Light'),
#   (('12/14/17', '03:47'), 'Birmingham', 'Light'),
#   (('12/13/17', '17:30'), 'Huntsville', 'Fireball'),
#   (('11/27/17', '11:20'), 'Chelsea', 'Cigar'),
#   (('11/26/17', '17:35'), 'Madison', 'Fireball'),
#   (('11/14/17', '21:00'), 'Huntsville', 'Triangle'),
#   (('11/13/17', '21:00'), 'Madison', 'Light'),
#   (('11/9/17', '15:00'), 'Anniston', 'Light'),
#   (('10/30/17', '19:00'), 'Enterprise', 'Light'),
#   (('10/24/17', '05:15'), 'Huntsville', 'Chevron'),
#   (('10/22/17', '18:00'), 'Anniston', 'Fireball'),
#   (('10/20/17', '18:30'), 'Lanett', 'Disk'),
#   (('10/20/17', '11:00'), 'Alabaster', 'Oval'),
#   (('10/18/17', '19:16'), 'Dora', 'Circle'),
#   (('10/18/17', '11:00'), 'Bay Minnette', 'Circle'),
#   (('10/17/17', '19:30'), 'Dora', 'Circle'),
#   (('9/15/17', '19:00'), 'Helena', 'Circle'),
#   (('9/10/17', '20:00'), 'Birmingham', 'Other'),
#   (('8/16/17', '16:00'), 'Vernon', 'Changing'),
#   (('8/15/17', '17:00'), 'Cold Springs (Bugtussel)', 'Triangle'),
#   (('8/8/17', '21:15'), 'Gulf Shores', 'Disk'),
#   (('8/8/17', '20:30'), 'Huntsville', 'Disk'),
#   (('7/20/17', '21:48'), 'Birmingham (outside Hueytown)', 'Formation'),
#   (('7/11/17', '14:00'), 'Birmingham (NE of)', 'Disk'),
#   (('6/24/17', '21:00'), 'Hazel Green', 'Rectangle'),
#   (('5/30/17', '21:15'), 'Anniston', 'Triangle'),
#   (('5/16/17', '09:50'), 'Hamilton', 'Triangle'),
#   (('5/9/17', '03:30'), 'Auburn', 'Circle'),
#   (('5/7/17', '20:00'), 'Montgomery', 'Circle'),
#   (('5/7/17', '19:30'), 'Warrior', 'Circle'),
#   (('4/29/17', '15:00'), 'Anniston', 'Cylinder'),
#   (('4/23/17', '19:00'), 'Birmingham', 'Oval'),
#   (('4/19/17', '23:55'), 'Newton', 'Triangle'),
#   (('4/19/17', '23:50'), 'Newton', 'Triangle'),
#   (('4/17/17', '03:58'), 'Jasper', 'Flash'),
#   (('4/15/17', '22:10'), 'Eastaboga', 'Light'),
#   (('4/15/17', '20:00'), 'Dothan', 'Light'),
#   (('4/14/17', '22:00'), 'Grant', 'Light'),
#   (('4/5/17', '20:00'), 'Lapine', 'Rectangle'),
#   (('3/21/17', '21:00'), 'Altoona', 'Triangle'),
#   (('3/15/17', '09:51'), 'Huntsville', 'Disk'),
#   (('3/9/17', '03:12'), 'Vestavia', 'Oval'),
#   (('3/3/17', '17:30'), 'Wetumpka', 'Sphere'),
#   (('2/26/17', '23:00'), 'Tuscaloosa', 'Light'),
#   (('2/22/17', '19:19'), 'Dothan', 'Circle'),
#   (('2/16/17', '07:18'), 'Maycomb', 'Disk'),
#   (('2/11/17', '17:20'), 'Summerdale', 'Light'),
#   (('2/2/17', '18:30'), 'Mobile', 'Fireball'),
#   (('1/29/17', '18:00'), 'Clio', 'Light'),
#   (('1/9/17', '03:02'), 'Birmingham', 'Changing'),
#   (('12/30/16', '14:42'), 'Huntsville', 'Formation'),
#   (('12/29/16', '22:00'), 'Hartselle', 'Triangle'),
#   (('12/22/16', '21:30'), 'New Brockton', 'Light'),
#   (('12/1/16', '17:30'), 'Montgomery', 'Circle'),
#   (('11/11/16', '23:00'), 'Alabaster', 'Light'),
#   (('11/2/16', '23:00'), 'Huntsville', 'Cigar'),
#   (('11/1/16', '18:30'), 'Phil Campbell', 'Light'),
#   (('10/30/16', '02:00'), 'Dothan', 'Circle'),
#   (('10/21/16', '23:30'), 'Cullman', 'Formation'),
#   (('10/12/16', '06:50'), 'Odenville', 'Light'),
#   (('10/5/16', '20:00'), 'Florence', 'Diamond'),
#   (('9/29/16', '22:10'), 'Phenix City', 'Egg'),
#   (('9/25/16', '20:30'), 'Wetumpka', 'Light'),
#   (('9/17/16', '00:00'), 'Athens', 'Oval'),
#   (('9/3/16', '06:00'), 'Hanceville', 'Light'),
#   (('8/3/16', '23:45'), 'Toney', 'Light'),
#   (('8/2/16', '05:15'), 'Ashville', 'Light'),
#   (('7/25/16', '20:30'), 'Phenix City', 'Triangle'),
#   (('7/23/16', '03:00'), 'Atmore', 'Rectangle'),
#   (('7/22/16', '10:00'), 'Mobile', 'Other'),
#   (('7/21/16', '22:10'), 'Spanish Fort', 'Triangle'),
#   (('7/7/16', '22:03'), 'Oxford', 'Other'),
#   (('7/4/16', '20:45'), 'Dothan', 'Circle'),
#   (('7/2/16', '20:38'), 'Lisman', 'Circle'),
#   (('7/1/16', '20:00'), 'Vestavia', 'Rectangle'),
#   (('7/1/16', '07:33'), 'Auburn', 'Light'),
#   (('6/23/16', '22:45'), 'Dothan', 'Circle'),
#   (('6/11/16', '21:30'), 'Dothan', 'Formation'),
#   (('5/15/16', '10:45'), 'Decatur', 'Cylinder'),
#   (('3/23/16', '12:30'), 'Tirana (Albania)', 'Cone'),
#   (('3/16/16', '20:30'), 'Anniston', 'Flash'),
#   (('3/15/16', '22:15'), 'Auburn', 'Sphere'),
#   (('3/6/16', '22:57'), 'Pelham', 'Sphere'),
#   (('2/25/16', '04:15'), 'Clements', 'Circle'),
#   (('2/19/16', '21:55'), 'Florence', 'Light'),
#   (('2/13/16', '21:30'), 'West Mobile', 'Fireball'),
#   (('2/3/16', '22:00'), 'Mobile', 'Oval'),
#   (('1/24/16', '18:43'), 'Montevallo', 'Light'),
#   (('1/8/16', '02:30'), 'Birmingham', 'Other'),
#   (('1/7/16', '20:30'), 'Clanton', 'Cylinder'),
#   (('1/6/16', '05:55'), 'Phenix city', 'Cone'),
#   (('1/5/16', '20:15'), 'Oxford', 'Triangle'),
#   (('12/31/15', '20:00'), 'Gadsden', 'Fireball'),
#   (('12/31/15', '19:00'), 'Southwest UK (UK/England)', 'Triangle'),
#   (('12/30/15', '20:00'), 'Harpersville', 'Oval'),
#   (('12/14/15', '21:15'), 'Dothan (general area)', 'Fireball'),
#   (('12/8/15', '21:00'), 'Athens', 'Diamond'),
#   (('12/8/15', '18:20'), 'Vance', 'Light'),
#   (('11/28/15', '20:00'), 'Dothan', 'Triangle'),
#   (('11/23/15', '03:00'), 'Hollywood', 'Light'),
#   (('11/22/15', '03:00'), 'Red Hill', 'Formation'),
#   (('11/16/15', '19:30'), 'Fort Payne', 'Light'),
#   (('11/12/15', '20:00'), 'Vandiver', 'Light'),
#   (('11/11/15', '18:00'), 'Hamilton', 'Circle'),
#   (('11/11/15', '17:20'), 'Rogersville', 'Light'),
#   (('11/11/15', '17:00'), 'Centre', 'Fireball'),
#   (('11/11/15', '15:00'), 'Florence', 'Sphere'),
#   (('11/4/15', '22:15'), 'Florence', 'Light'),
#   (('11/2/15', '16:00'), 'Wicksburg', 'Light'),
#   (('10/29/15', '04:15'), 'Stapleton', 'Light'),
#   (('10/22/15', '03:51'), 'Crane Hill', 'Fireball'),
#   (('10/21/15', '22:38'), 'Valley', 'Triangle'),
#   (('10/19/15', '19:45'), 'Waverly', 'Light'),
#   (('10/11/15', '04:30'), 'Mobile', 'Other'),
#   (('10/10/15', '20:40'), 'Thorsby', 'Light'),
#   (('10/10/15', '18:00'), 'Florence', 'Light'),
#   (('9/18/15', '20:00'), 'Lisman', 'Light'),
#   (('9/18/15', '19:20'), 'Jones', 'Oval'),
#   (('9/16/15', '20:20'), 'Littleville', 'Light'),
#   (('9/15/15', '20:20'), 'Tuscumbia', 'Light'),
#   (('9/15/15', '19:00'), 'Nanafalia', 'Light'),
#   (('9/15/15', '18:15'), 'Dothan', 'Light'),
#   (('9/12/15', '19:45'), 'Tuscumbia', 'Light'),
#   (('9/1/15', '01:00'), 'Kentucky', 'Disk'),
#   (('8/26/15', '23:00'), 'Spanish Fort', 'Fireball'),
#   (('8/12/15', '00:00'), 'Gulf shores', 'Fireball'),
#   (('8/10/15', '19:13'), 'Hartford', 'Triangle'),
#   (('8/10/15', '03:00'), 'Homewood', 'Light'),
#   (('7/20/15', '22:15'), 'Huntsville', 'Chevron'),
#   (('7/16/15', '22:00'), 'Fairhope', 'Fireball'),
#   (('7/11/15', '21:15'), 'Montgomery', 'Fireball'),
#   (('7/4/15', '21:00'), 'Montgomery', 'Light'),
#   (('7/3/15', '21:00'), 'Elberta', 'Fireball'),
#   (('6/29/15', '00:30'), 'Huntsville (Owens Cross Roads)', 'Other'),
#   (('6/15/15', '22:45'), 'Hoover', 'Light'),
#   (('6/14/15', '18:00'), 'Birmingham', 'Light'),
#   (('6/9/15', '10:00'), 'Leeds', 'Triangle'),
#   (('6/4/15', '20:00'), 'Gulf Shores', 'Light'),
#   (('4/11/15', '22:15'), 'Harvest', 'Light'),
#   (('1/28/15', '20:00'), 'Semmes', 'Circle'),
#   (('1/28/15', '20:00'), 'Florala', 'Light'),
#   (('1/18/15', '18:35'), 'Mobile', 'Light'),
#   (('1/18/15', '17:50'), 'Florence', 'Sphere'),
#   (('1/17/15', '20:25'), 'Mobile', 'Light'),
#   (('1/17/15', '18:35'), 'Ranburne', 'Light'),
#   (('1/9/15', '18:45'), 'Shelby (Lay Lake)', 'Light'),
#   (('1/5/15', '20:00'), 'Birmingham', 'Light'),
#   (('12/26/14', '20:45'), 'Chelsea', 'Triangle'),
#   (('12/14/14', '00:30'), 'Mobile', 'Other'),
#   (('12/11/14', '16:40'), 'Birmingham', 'Fireball'),
#   (('12/11/14', '16:20'), 'Hoover', 'Light'),
#   (('12/4/14', '19:00'), 'Attalla', 'Light'),
#   (('11/21/14', '20:00'), 'Rockford', 'Cigar'),
#   (('11/20/14', '20:00'), 'Florence', 'Light'),
#   (('11/19/14', '00:00'), 'Mobile', 'Changing'),
#   (('11/18/14', '18:00'), 'Albertville', 'Light'),
#   (('11/17/14', '22:30'), 'Trussville', 'Cross'),
#   (('11/13/14', '17:00'), 'Columbia', 'Formation'),
#   (('11/6/14', '19:00'), 'Greendale', 'Sphere'),
#   (('11/6/14', '18:00'), 'Phenix City', 'Other'),
#   (('11/2/14', '23:00'), 'Robertsdale', 'Light'),
#   (('10/22/14', '19:45'), 'Phenix city', 'Light'),
#   (('10/20/14', '19:55'), 'Huntsville', 'Changing'),
#   (('10/18/14', '11:30'), 'Somerville', 'Formation'),
#   (('10/16/14', '21:30'), 'Panama City', 'Fireball'),
#   (('10/14/14', '20:30'), 'Phenix City', 'Light'),
#   (('10/6/14', '19:48'), 'Valley', 'Light'),
#   (('9/25/14', '20:45'), 'Homewood', 'Formation'),
#   (('9/24/14', '18:25'), 'Hoover', 'Circle'),
#   (('9/20/14', '21:30'), 'Jacksonville', 'Light'),
#   (('9/17/14', '21:33'), 'Valley', 'Light'),
#   (('9/17/14', '20:35'), 'Valley', 'Light'),
#   (('9/17/14', '20:00'), 'Warrior', 'Light'),
#   (('9/16/14', '19:30'), 'Millry', 'Light'),
#   (('9/14/14', '22:15'), 'Hoover', 'Egg'),
#   (('9/12/14', '21:30'), 'Grant', 'Formation'),
#   (('9/5/14', '19:30'), 'Huntsville', 'Cigar'),
#   (('8/26/14', '20:30'), 'Deatsville', 'Light'),
#   (('8/23/14', '23:20'), 'Old AL Hwy. 35 (between MM 8-10)', 'Sphere'),
#   (('8/23/14', '23:00'), 'Cherokee', 'Light'),
#   (('8/11/14', '21:00'), 'Cordova', 'Flash'),
#   (('8/2/14', '22:00'), 'Madison/east Limestone', 'Light'),
#   (('7/19/14', '02:00'), 'Theodore', 'Fireball'),
#   (('7/16/14', '23:00'), 'Brundidge', 'Light'),
#   (('7/16/14', '22:30'), 'Phenix City', 'Light'),
#   (('7/16/14', '21:50'), 'Luverne', 'Flash'),
#   (('7/16/14', '20:47'), 'Rogersville', 'Rectangle'),
#   (('7/14/14', '19:40'), 'Helena', 'Light'),
#   (('7/10/14', '21:15'), 'Andalusia', 'Fireball'),
#   (('7/6/14', '20:45'), 'Calera', 'Fireball'),
#   (('7/5/14', '22:00'), 'Lanett', 'Fireball'),
#   (('7/4/14', '23:00'), 'Mobile', 'Sphere'),
#   (('7/4/14', '22:05'), 'Birmingham', 'Fireball'),
#   (('7/4/14', '21:45'), 'Madison', 'Circle'),
#   (('7/4/14', '21:15'), 'East Limestone', 'Circle'),
#   (('7/4/14', '21:00'), 'Daphne', 'Circle'),
#   (('7/4/14', '09:00'), 'Ashville', 'Sphere'),
#   (('7/3/14', '20:00'), 'Glencoe', 'Chevron'),
#   (('6/30/14', '21:50'), 'Madison', 'Formation'),
#   (('6/27/14', '23:00'), 'Geraldine', 'Disk'),
#   (('6/27/14', '21:00'), 'Jacksonville', 'Circle'),
#   (('6/26/14', '23:00'), 'Glencoe', 'Light'),
#   (('6/19/14', '20:50'), 'Rainbow City', 'Fireball'),
#   (('6/17/14', '21:15'), 'Fort Morgan', 'Formation'),
#   (('6/3/14', '18:25'), 'Tuscaloosa', 'Other'),
#   (('5/30/14', '21:30'), 'Scottsboro', 'Light'),
#   (('5/30/14', '21:30'), 'Madison', 'Formation'),
#   (('5/25/14', '22:30'), 'Fairhope', 'Light'),
#   (('5/17/14', '05:04'), 'Gardendale', 'Sphere'),
#   (('5/15/14', '14:00'), 'Oneonta', 'Cigar'),
#   (('5/10/14', '20:00'), 'mobile', 'Sphere'),
#   (('5/8/14', '21:00'), 'Dauphin Island', 'Formation'),
#   (('5/8/14', '21:00'), 'Dauphin Island', 'Light'),
#   (('5/7/14', '03:30'), 'Calera', 'Circle'),
#   (('5/6/14', '20:35'), 'Gadsden', 'Cylinder'),
#   (('5/6/14', '20:08'), 'Grand Bay', 'Circle'),
#   (('5/2/14', '20:38'), 'Belgreen', 'Formation'),
#   (('5/1/14', '20:48'), 'Boaz', 'Other'),
#   (('5/1/14', '20:30'), 'Huntsville', 'Other'),
#   (('5/1/14', '17:00'), 'Orange Beach', 'Formation'),
#   (('4/26/14', '22:30'), 'Cottonwood', 'Circle'),
#   (('4/25/14', '22:30'), 'Theodore', 'Fireball'),
#   (('4/24/14', '21:00'), 'Orange Beach', 'Formation'),
#   (('4/24/14', '20:30'), 'Dauphin Island (off the coast of)', 'Light'),
#   (('4/23/14', '22:15'), 'Dauphin Island', 'Formation'),
#   (('4/23/14', '20:08'), 'Dauphin Island', 'Light'),
#   (('4/16/14', '17:00'), 'Mobile', 'Other'),
#   (('4/16/14', '14:10'), 'Huntsville', 'Cross'),
#   (('4/13/14', '21:00'), 'Huntsville', 'Light'),
#   (('4/5/14', '20:30'), 'Hazel Green', 'Light'),
#   (('4/3/14', '14:00'), 'Muscle Shoals', 'Cylinder'),
#   (('3/16/14', '20:10'), 'Birmingham', 'Light'),
#   (('3/10/14', '14:35'), 'Russellville', 'Cigar'),
#   (('3/10/14', '00:30'), 'Montevallo', 'Flash'),
#   (('3/7/14', '15:47'), 'Mountain Brook', 'Light'),
#   (('3/5/14', '20:07'), 'Lacy Springs', 'Triangle'),
#   (('2/27/14', '21:00'), 'Montgomery/Millbrook', 'Triangle'),
#   (('2/22/14', '19:00'), 'Dothan', 'Fireball'),
#   (('2/18/14', '08:15'), 'Toney', 'Disk'),
#   (('2/18/14', '08:15'), 'Toney', 'Oval'),
#   (('2/17/14', '00:14'), 'Cusseta & Fairfax', 'Light'),
#   (('1/30/14', '22:30'), 'Talladega', 'Triangle'),
#   (('1/23/14', '02:00'), 'Huntsville', 'Triangle'),
#   (('1/20/14', '19:30'), 'Madison', 'Triangle'),
#   (('1/16/14', '18:27'), 'Birmingham', 'Formation'),
#   (('1/15/14', '19:30'), 'Birmingham', 'Formation'),
#   (('1/15/14', '17:45'), 'Mountain Brook', 'Light'),
#   (('1/12/14', '13:35'), 'Huntsville', 'Disk'),
#   (('1/1/14', '00:20'), 'Hokes Bluff', 'Circle'),
#   (('1/1/14', '00:00'), 'Trussville', 'Light'),
#   (('12/31/13', '23:00'), 'Huntsville', 'Changing'),
#   (('12/26/13', '22:30'), 'Foley', 'Diamond'),
#   (('12/20/13', '17:00'), 'Alabaster', 'Fireball'),
#   (('12/16/13', '22:15'), 'Alabaster', 'Other'),
#   (('12/14/13', '00:00'), 'Hurtsboro', 'Triangle'),
#   (('12/9/13', '23:15'), 'Mobile', 'Other'),
#   (('11/27/13', '22:40'), 'Guntersville', 'Formation'),
#   (('11/18/13', '11:30'), 'Pelham', 'Light'),
#   (('11/7/13', '18:30'), 'Mobile', 'Light'),
#   (('11/6/13', '19:30'), 'Dothan', 'Circle'),
#   (('11/6/13', '19:30'), 'Wadley', 'Sphere'),
#   (('11/3/13', '19:00'), 'Huntsville', 'Light'),
#   (('10/23/13', '02:00'), 'Parrish Alabama', 'Light'),
#   (('10/8/13', '18:30'), 'Mobile', 'Oval'),
#   (('10/6/13', '23:11'), 'Opelika', 'Flash'),
#   (('10/5/13', '21:15'), 'Daphne', 'Light'),
#   (('10/4/13', '21:55'), 'Madison', 'Cylinder'),
#   (('10/4/13', '21:55'), 'Madison', 'Circle'),
#   (('9/28/13', '21:45'), 'Florence', 'Sphere'),
#   (('9/28/13', '18:47'), 'Chelsea', 'Fireball'),
#   (('9/27/13', '19:35'), 'Hoover', 'Disk'),
#   (('9/18/13', '11:00'), 'Hamilton', 'Fireball'),
#   (('9/14/13', '19:45'), 'Gardendale', 'Sphere'),
#   (('9/9/13', '20:20'), 'Tuscaloosa', 'Fireball'),
#   (('9/7/13', '21:00'), 'Peidmont', 'Light'),
#   (('8/15/13', '17:30'), 'Fairhope', 'Disk'),
#   (('8/4/13', '20:10'), 'Harvest', 'Fireball'),
#   (('8/4/13', '20:10'), 'Gurley', 'Circle'),
#   (('8/2/13', '21:00'), 'Gulf Shores', 'Light'),
#   (('8/1/13', '03:00'), 'McCalla', 'Other'),
#   (('7/29/13', '18:35'), 'Madison', 'Egg'),
#   (('7/29/13', '18:35'), 'Madison', 'Egg'),
#   (('7/27/13', '22:30'), 'Huntsville', 'Fireball'),
#   (('7/13/13', '00:00'), 'Eufaula (close to)', 'Light'),
#   (('7/12/13', '21:08'), 'Gulf Shores', 'Circle'),
#   (('7/12/13', '20:00'), 'Jacksonville', 'Circle'),
#   (('7/11/13', '20:50'), 'Fort Morgan', 'Light'),
#   (('7/7/13', '20:30'), 'Elkmont', 'Formation'),
#   (('7/6/13', '21:10'), 'Hoover', 'Circle'),
#   (('7/5/13', '20:36'), 'Birmingham', 'Fireball'),
#   (('7/2/13', '01:38'), 'Blountsville', 'Triangle'),
#   (('7/1/13', '20:00'), 'Heflin', 'Circle'),
#   (('6/30/13', '14:00'), 'Huntsville', 'Sphere'),
#   (('6/30/13', '02:30'), 'Sheffield', 'Triangle'),
#   (('6/11/13', '21:30'), 'Huntsville', 'Sphere'),
#   (('6/4/13', '17:35'), 'Helena', 'Formation'),
#   (('6/4/13', '10:00'), 'Woodville', 'Light'),
#   (('6/3/13', '09:30'), 'Huntsville', 'Light'),
#   (('5/30/13', '21:30'), 'Foley', 'Light'),
#   (('5/26/13', '22:00'), 'Wedowee', 'Fireball'),
#   (('5/26/13', '22:00'), 'Wedowee', 'Fireball'),
#   (('5/24/13', '18:30'), 'Luverne (near)', 'Other'),
#   (('5/20/13', '21:45'), 'Athens', 'Flash'),
#   (('5/10/13', '22:00'), 'Huntsville', 'Light'),
#   (('5/7/13', '18:00'), 'Pell City', 'Oval'),
#   (('4/26/13', '23:00'), 'Prattville', 'Light'),
#   (('4/26/13', '20:20'), 'Birmingham', 'Light'),
#   (('4/25/13', '10:43'), 'Foley/Elberta', 'Flash'),
#   (('4/8/13', '19:07'), 'Northport', 'Light'),
#   (('3/29/13', '10:35'), 'Kellyton', 'Cylinder'),
#   (('3/17/13', '11:44'), 'Gulf Shores', 'Triangle'),
#   (('3/15/13', '20:19'), 'Alabaster', 'Fireball'),
#   (('3/15/13', '04:00'), 'Huntsville', 'Triangle'),
#   (('3/11/13', '18:00'), 'Tuscaloosa', 'Fireball'),
#   (('3/9/13', '21:00'), 'Cullman', 'Diamond'),
#   (('3/7/13', '19:30'), 'Brookside', 'Cigar'),
#   (('2/3/13', '20:00'), 'Sylacauga', 'Triangle'),
#   (('1/31/13', '23:00'), 'Brewton', 'Flash'),
#   (('1/31/13', '05:30'), 'Nixburg', 'Sphere'),
#   (('1/21/13', '16:50'), 'New Hope', 'Changing'),
#   (('1/20/13', '21:00'), 'Flomaton', 'Circle'),
#   (('1/6/13', '20:30'), 'Moundville', 'Triangle'),
#   (('12/31/12', '19:15'), 'Selma', 'Changing'),
#   (('12/27/12', '19:00'), 'Foley', 'Light'),
#   (('12/23/12', '15:00'), 'Opp', 'Light'),
#   (('12/21/12', '11:00'), 'Moundville', 'Sphere'),
#   (('12/20/12', '21:30'), 'Greenville', 'Triangle'),
#   (('12/18/12', '15:35'), 'Attalla', 'Light'),
#   (('12/13/12', '19:15'), 'Homewood', 'Light'),
#   (('12/9/12', '09:55'), 'Gardendale', 'Light'),
#   (('12/3/12', '05:25'), 'Birmingham', 'Sphere'),
#   (('12/2/12', '18:00'), 'Gordo', 'Fireball'),
#   (('11/24/12', '20:25'), 'Montgomery', 'Circle'),
#   (('11/21/12', '21:30'), 'Jasper', 'Fireball'),
#   (('11/19/12', '19:00'), 'Irondale', 'Light'),
#   (('11/13/12', '05:37'), 'Birmingham', 'Egg'),
#   (('11/1/12', '21:00'), 'Oneonta', 'Triangle'),
#   (('10/17/12', '03:20'), 'Birmingham', 'Light'),
#   (('10/15/12', '21:00'), 'Somerville', 'Changing'),
#   (('10/13/12', '06:30'), 'Cedar Bluff', 'Circle'),
#   (('10/10/12', '20:00'), 'Moundville', 'Changing'),
#   (('9/29/12', '17:00'), 'Athens', 'Fireball'),
#   (('9/22/12', '22:30'), 'Hoover', 'Flash'),
#   (('9/22/12', '17:45'), 'Randburg (South Africa)', 'Disk'),
#   (('9/15/12', '05:20'), 'Huntsville', 'Light'),
#   (('8/22/12', '19:00'), 'Hoover', 'Light'),
#   (('8/22/12', '13:10'), 'Madison', 'Light'),
#   (('8/15/12', '19:00'), 'Alabaster', 'Cylinder'),
#   (('8/7/12', '22:00'), 'Coffeville', 'Light'),
#   (('8/5/12', '19:40'), 'Alabaster', 'Cigar'),
#   (('7/20/12', '21:30'), 'Robertsdale', 'Light'),
#   (('7/18/12', '14:00'), 'Hartselle', 'Fireball'),
#   (('7/4/12', '23:23'), 'Birmingham', 'Oval'),
#   (('6/26/12', '21:39'), 'Trussville', 'Oval'),
#   (('6/25/12', '22:30'), 'Foley', 'Diamond'),
#   (('6/24/12', '15:00'), 'Gordo', 'Light'),
#   (('6/13/12', '21:30'), 'Mobile Bay', 'Fireball'),
#   (('6/13/12', '20:00'), 'Dauphin Island', 'Sphere'),
#   (('5/28/12', '08:15'), 'Theodore', 'Light'),
#   (('5/22/12', '22:30'), 'Florence', 'Light'),
#   (('5/19/12', '16:40'), 'Montgomery', 'Flash'),
#   (('5/12/12', '22:00'), 'Bay Minette', 'Circle'),
#   (('5/4/12', '15:00'), 'Centre', 'Cylinder'),
#   (('5/3/12', '21:00'), 'Oxford', 'Fireball'),
#   (('4/29/12', '21:00'), 'Birmingham', 'Cross'),
#   (('4/18/12', '09:00'), 'Grand Bay', 'Circle'),
#   (('4/10/12', '20:10'), 'Spanish Fort', 'Diamond'),
#   (('4/10/12', '20:00'), 'Spanish Fort', 'Diamond'),
#   (('4/7/12', '23:00'), 'Citronelle', 'Triangle'),
#   (('3/25/12', '16:00'), 'Oneonta', 'Circle'),
#   (('3/21/12', '20:45'), 'Huntsville', 'Sphere'),
#   (('2/12/12', '05:00'), 'Shelby', 'Rectangle'),
#   (('2/9/12', '20:00'), 'Madison', 'Light'),
#   (('2/7/12', '20:55'), 'Adamsville', 'Sphere'),
#   (('1/18/12', '18:00'), 'Valley Grande', 'Triangle'),
#   (('1/11/12', '18:35'), 'Mobile', 'Light'),
#   (('1/3/12', '00:19'), 'Eufaula', 'Light'),
#   (('12/31/11', '21:00'), 'Birmingham', 'Circle'),
#   (('11/20/11', '22:00'), 'Millbrook', 'Egg'),
#   (('11/16/11', '20:00'), 'Irvington', 'Circle'),
#   (('11/6/11', '06:30'), 'Dothan', 'Light'),
#   (('10/27/11', '17:00'), 'Tuscaloosa', 'Circle'),
#   (('10/26/11', '20:15'), 'Hamilton', 'Light'),
#   (('10/26/11', '20:10'), 'Hamilton', 'Diamond'),
#   (('10/21/11', '19:30'), 'Ardmore', 'Light'),
#   (('10/21/11', '19:00'),
#    'Pelham (Valleydale exit getting onto I-65 N)',
#    'Circle'),
#   (('10/20/11', '21:15'), 'Orange Beach', 'Circle'),
#   (('10/15/11', '19:00'), 'Toney', 'Circle'),
#   (('10/14/11', '20:35'), 'Eufaula', 'Light'),
#   (('10/13/11', '20:38'), 'Gurley', 'Diamond'),
#   (('9/21/11', '07:00'), 'Arley', 'Fireball'),
#   (('9/17/11', '21:30'), 'Chelsea', 'Oval'),
#   (('9/9/11', '10:20'), 'Double Springs', 'Sphere'),
#   (('9/9/11', '08:30'), 'Arley', 'Sphere'),
#   (('9/1/11', '21:00'), 'Jacksonville', 'Light'),
#   (('8/23/11', '05:00'), 'Athens (Hwy 72 W)', 'Light'),
#   (('8/16/11', '05:50'), 'Albertville', 'Circle'),
#   (('7/29/11', '17:20'), 'Hoover', 'Other'),
#   (('7/6/11', '18:45'), 'Doha (Qatar)', 'Sphere'),
#   (('7/4/11', '22:00'), 'Huntsville', 'Circle'),
#   (('7/4/11', '21:30'), 'Madison', 'Light'),
#   (('7/2/11', '21:32'), 'Maylene', 'Fireball'),
#   (('6/15/11', '23:00'), 'Perdue Hill', 'Oval'),
#   (('5/20/11', '22:34'), 'Mobile', 'Triangle'),
#   (('5/17/11', '22:30'), 'Anniston', 'Fireball'),
#   (('5/6/11', '22:10'), 'Huntsville', 'Triangle'),
#   (('4/13/11', '22:30'), 'Fort Payne', 'Oval'),
#   (('4/6/11', '20:22'), 'Athens-East Limestone', 'Other'),
#   (('2/11/11', '18:40'), 'Boilgee', 'Light'),
#   (('1/12/11', '23:00'), 'Mobile', 'Flash'),
#   (('1/2/11', '05:30'), 'Seminole', 'Teardrop'),
#   (('12/27/10', '17:00'), 'Alabaster', 'Circle'),
#   (('12/13/10', '23:45'), 'Eufaula', 'Light'),
#   (('12/5/10', '21:00'), 'Huntsvile', 'Formation'),
#   (('12/1/10', '08:20'), 'Huntsville', 'Other'),
#   (('11/18/10', '23:00'), 'Oxford', 'Circle'),
#   (('11/17/10', '04:30'), 'Gadsden', 'Sphere'),
#   (('10/16/10', '15:00'), 'Cullman', 'Sphere'),
#   (('10/14/10', '18:30'), 'Foley', 'Cylinder'),
#   (('10/12/10', '19:13'), 'Daphne', 'Chevron'),
#   (('10/4/10', '00:30'), 'Birmingham', 'Triangle'),
#   (('7/25/10', '20:40'), 'Troy to Montgomery', 'Circle'),
#   (('7/24/10', '22:00'), 'Florence', 'Light'),
#   (('7/21/10', '10:46'), 'Brantley', 'Triangle'),
#   (('7/11/10', '13:00'), 'Frankfort', 'Chevron'),
#   (('7/10/10', '22:45'), 'Gadsden', 'Light'),
#   (('7/4/10', '20:50'), 'Huntsville', 'Other'),
#   (('6/20/10', '16:40'), 'Anniston', 'Oval'),
#   (('6/15/10', '21:30'), 'Saraland', 'Light'),
#   (('5/17/10', '22:20'), 'Grant', 'Teardrop'),
#   (('3/12/10', '20:30'), 'McKenzie', 'Triangle'),
#   (('1/2/10', '21:10'), 'Madison', 'Triangle'),
#   (('12/7/09', '23:00'), 'Smiths Station', 'Diamond'),
#   (('11/12/09', '05:08'), 'Deatsville', 'Light'),
#   (('11/10/09', '01:00'), 'Birmingham', 'Triangle'),
#   (('10/15/09', '23:00'), 'Dothan', 'Flash'),
#   (('10/15/09', '18:00'), 'Ozark', 'Other'),
#   (('9/16/09', '21:54'), 'Dothan', 'Diamond'),
#   (('9/14/09', '19:40'), 'Warrior', 'Sphere'),
#   (('9/9/09', '17:05'), 'Birmingham', 'Other'),
#   (('9/9/09', '08:17'), 'Franklin County', 'Chevron'),
#   (('8/31/09', '05:00'), 'Tuscaloosa', 'Light'),
#   (('8/23/09', '01:00'), 'Spanish Fort', 'Light'),
#   (('8/11/09', '22:00'), 'Phenix city', 'Triangle'),
#   (('8/4/09', '23:00'), 'McCalla', 'Changing'),
#   (('7/25/09', '21:40'), 'Semmes', 'Light'),
#   (('7/20/09', '09:30'), 'Auburn', 'Light'),
#   (('7/10/09', '23:00'), 'Bear Creek', 'Circle'),
#   (('7/7/09', '15:28'), 'Satsuma', 'Cigar'),
#   (('5/17/09', '11:00'), 'Jasper', 'Cigar'),
#   (('3/24/09', '20:26'), 'Montevallo', 'Triangle'),
#   (('3/20/09', '03:30'), 'Andalusia', 'Disk'),
#   (('2/25/09', '20:00'), 'Tuscaloosa', 'Sphere'),
#   (('2/16/09', '18:50'), 'Dothan', 'Triangle'),
#   (('2/12/09', '23:30'), 'Rehobeth', 'Triangle'),
#   (('2/5/09', '17:15'), 'Madison', 'Other'),
#   (('2/4/09', '07:00'), 'North Mobile County', 'Cigar'),
#   (('1/25/09', '01:00'), 'Sylvania', 'Circle'),
#   (('1/15/09', '18:15'), 'Birmingham', 'Light'),
#   (('1/9/09', '09:00'), 'Huntsville', 'Other'),
#   (('12/21/08', '19:30'), 'Citronelle', 'Sphere'),
#   (('12/14/08', '02:00'), 'Anniston', 'Light'),
#   (('11/24/08', '19:00'), 'Phenix City & Columbus,Ga', 'Light'),
#   (('11/19/08', '22:10'), 'Tuscaloosa', 'Cigar'),
#   (('11/18/08', '07:40'), 'Prattville', 'Disk'),
#   (('11/3/08', '21:00'), 'Fairview', 'Sphere'),
#   (('10/18/08', '01:00'), 'Gardendale', 'Sphere'),
#   (('10/9/08', '12:24'), 'Auburn', 'Circle'),
#   (('10/1/08', '11:00'), 'Pell City', 'Cigar'),
#   (('9/26/08', '19:30'), 'Bay Minette', 'Light'),
#   (('9/4/08', '06:15'), 'Eldridge', 'Diamond'),
#   (('8/28/08', '22:30'), 'Leighton', 'Fireball'),
#   (('8/27/08', '01:26'), 'Anniston', 'Circle'),
#   (('8/11/08', '02:15'), 'Petersville', 'Triangle'),
#   (('7/15/08', '21:00'), 'Scottsboro', 'Sphere'),
#   (('7/7/08', '00:15'), 'Chelsea', 'Triangle'),
#   (('7/6/08', '01:45'), 'Sylacauga', 'Rectangle'),
#   (('7/5/08', '20:00'), 'Sheffield', 'Light'),
#   (('6/27/08', '08:00'), 'Gardendale', 'Disk'),
#   (('6/9/08', '20:36'), 'Adamsville', 'Sphere'),
#   (('6/1/08', '17:00'), 'Dothan', 'Other'),
#   (('5/23/08', '02:15'), 'Athens', 'Light'),
#   (('5/10/08', '22:00'), 'Scottsboro', 'Oval'),
#   (('4/25/08', '16:40'), 'Madison', 'Sphere'),
#   (('4/23/08', '01:30'), 'Addison', 'Disk'),
#   (('4/22/08', '22:30'), 'Saraland', 'Egg'),
#   (('4/20/08', '18:45'), 'Dothan', 'Diamond'),
#   (('4/20/08', '04:00'), 'Gulf Shores', 'Circle'),
#   (('4/11/08', '22:30'), 'Bessemer (near)', 'Light'),
#   (('4/3/08', '07:15'), 'Birmingham', 'Cigar'),
#   (('4/1/08', '03:30'), 'Tuscaloosa', 'Other'),
#   (('3/22/08', '21:00'), 'Lanett', 'Circle'),
#   (('3/21/08', '05:45'), 'Borden Springs', 'Cigar'),
#   (('3/16/08', '23:16'), 'Birmingham', 'Triangle'),
#   (('3/14/08', '04:00'), 'Tuscaloosa', 'Other'),
#   (('2/23/08', '21:00'), 'Dutton', 'Changing'),
#   (('1/28/08', '15:30'), 'Livingston', 'Cigar'),
#   (('1/24/08', '23:30'), 'Florence', 'Teardrop'),
#   (('1/24/08', '19:00'), 'Valley', 'Fireball'),
#   (('1/20/08', '22:09'), 'Haleyville', 'Triangle'),
#   (('12/12/07', '21:00'), 'Birmingham', 'Cylinder'),
#   (('12/11/07', '21:00'), 'Madison', 'Circle'),
#   (('12/11/07', '21:00'), 'Madison', 'Disk'),
#   (('12/10/07', '18:03'), 'Dora', 'Changing'),
#   (('12/10/07', '18:00'), 'Gardendale', 'Other'),
#   (('12/10/07', '17:30'), 'Shelby', 'Circle'),
#   (('11/19/07', '04:00'), 'Huntsville', 'Light'),
#   (('11/8/07', '23:15'), 'Mobile', 'Fireball'),
#   (('10/11/07', '20:30'), 'Gulf Shores', 'Disk'),
#   (('9/14/07', '23:23'), 'Jackson', 'Triangle'),
#   (('9/10/07', '02:00'), 'Robertsdale', 'Cylinder'),
#   (('8/19/07', '20:30'), 'Birmingham', 'Disk'),
#   (('7/25/07', '21:00'), 'Fort Morgan', 'Light'),
#   (('7/22/07', '06:30'), 'Birmingham', 'Chevron'),
#   (('7/6/07', '16:00'), 'Alabama (above; in flight)', 'Other'),
#   (('7/3/07', '21:30'), 'Southside', 'Triangle'),
#   (('6/30/07', '22:00'), 'Orange Beach', 'Circle'),
#   (('6/26/07', '21:00'), 'Gulf Shores', 'Light'),
#   (('6/25/07', '02:20'), 'Prattville', 'Triangle'),
#   (('6/23/07', '21:10'), 'Grand Bay', 'Fireball'),
#   (('6/21/07', '23:15'), 'Mobile', 'Fireball'),
#   (('6/6/07', '22:00'), 'Gulf Shores', 'Changing'),
#   (('6/6/07', '22:00'), 'Fort Morgan', 'Light'),
#   (('6/4/07', '21:35'), 'Valley', 'Sphere'),
#   (('6/3/07', '21:00'), 'Orange Beach', 'Light'),
#   (('5/10/07', '21:00'), 'Anniston', 'Light'),
#   (('4/28/07', '19:30'), 'Australia', 'Light'),
#   (('4/27/07', '22:00'), 'Madison', 'Light'),
#   (('4/23/07', '08:00'), 'Elmore', 'Triangle'),
#   (('4/17/07', '21:00'), 'Auburn', 'Other'),
#   (('4/12/07', '21:00'), 'Madison', 'Light'),
#   (('4/6/07', '20:45'), 'Jacksonville', 'Diamond'),
#   (('4/5/07', '19:00'), 'Huntsville', 'Triangle'),
#   (('2/28/07', '20:00'), 'Madison', 'Triangle'),
#   (('2/28/07', '18:00'), 'Athens', 'Triangle'),
#   (('2/28/07', '09:00'), 'Eastaboga', 'Other'),
#   (('2/25/07', '21:30'), 'Auburn', 'Light'),
#   (('1/23/07', '21:00'), 'Hoover', 'Triangle'),
#   (('1/16/07', '18:00'), 'Woodville', 'Light'),
#   (('1/5/07', '20:59'), 'Huntsville', 'Light'),
#   (('1/1/07', '23:30'), 'Birmingham', 'Disk'),
#   (('12/17/06', '19:58'), 'Opp', 'Circle'),
#   (('12/2/06', '12:15'), 'Satsuma', 'Oval'),
#   (('11/28/06', '17:30'), 'Bremen', 'Fireball'),
#   (('11/28/06', '17:30'), 'Huntsville', 'Light'),
#   (('11/28/06', '17:30'), 'Birmingham', 'Sphere'),
#   (('11/28/06', '17:30'), 'Birmingham', 'Circle'),
#   (('11/28/06', '17:30'), 'Birmingham', 'Light'),
#   (('11/28/06', '17:30'), 'Birmingham', 'Fireball'),
#   (('11/28/06', '17:25'), 'Pinson', 'Fireball'),
#   (('11/28/06', '05:30'), 'Birmingham', 'Light'),
#   (('11/27/06', '22:06'), 'Huntsville', 'Fireball'),
#   (('11/22/06', '21:00'), 'Athens', 'Triangle'),
#   (('11/15/06', '01:00'), 'Birmingham', 'Fireball'),
#   (('10/20/06', '11:30'), 'Birmingham', 'Sphere'),
#   (('9/1/06', '17:00'), 'Hoover', 'Fireball'),
#   (('8/27/06', '21:00'), 'Madison', 'Formation'),
#   (('8/22/06', '20:00'), 'Toney', 'Triangle'),
#   (('8/13/06', '21:00'), 'Huntsville', 'Oval'),
#   (('8/8/06', '08:30'), 'Boaz', 'Oval'),
#   (('7/19/06', '03:30'), 'Montgomery', 'Disk'),
#   (('7/5/06', '21:30'), 'Florence', 'Light'),
#   (('6/8/06', '22:00'), 'Atmore', 'Other'),
#   (('5/23/06', '22:30'), 'Moulton', 'Light'),
#   (('4/16/06', '09:54'), 'Hoover', 'Other'),
#   (('3/30/06', '19:15'), 'Lawley', 'Egg'),
#   (('2/10/06', '20:00'), 'Cusseta', 'Light'),
#   (('1/3/06', '18:50'), 'Aliceville/Carrolton/Livingston', 'Sphere'),
#   (('12/30/05', '13:25'), 'Melbourne (Australia)', 'Disk'),
#   (('12/21/05', '17:00'), 'Hoover', 'Other'),
#   (('12/19/05', '11:00'), 'Foely', 'Oval'),
#   (('12/2/05', '00:00'), 'Montgomery', 'Rectangle'),
#   (('12/1/05', '18:00'), 'Gadsden (south side of)', 'Other'),
#   (('11/29/05', '07:44'), 'Grove Hill', 'Triangle'),
#   (('11/28/05', '09:10'), 'Guaymas Sonora (Mexico)', 'Fireball'),
#   (('11/19/05', '18:30'), 'Gurley', 'Circle'),
#   (('11/8/05', '05:11'), 'Enterprise', 'Light'),
#   (('10/21/05', '20:00'), 'Heflin', 'Sphere'),
#   (('10/13/05', '20:00'), 'Millbrook', 'Changing'),
#   (('10/11/05', '19:45'), 'Mobile', 'Light'),
#   (('10/4/05', '19:00'), 'Auburn', 'Oval'),
#   (('10/4/05', '19:00'), 'Huntsville', 'Circle'),
#   (('8/30/05', '00:00'), 'Mobile', 'Flash'),
#   (('8/19/05', '21:00'), 'Hueytown', 'Sphere'),
#   (('8/17/05', '12:00'), 'Fort Payne', 'Triangle'),
#   (('8/15/05', '21:45'), 'Mount Olive', 'Disk'),
#   (('8/10/05', '22:10'), 'Hazel Green', 'Light'),
#   (('7/25/05', '03:45'), 'Huntsville', 'Oval'),
#   (('7/8/05', '22:45'), 'Tuscaloosa', 'Circle'),
#   (('6/20/05', '21:50'), 'Gulf Shores', 'Light'),
#   (('6/19/05', '18:10'), 'Huntsville', 'Circle'),
#   (('6/14/05', '04:00'), 'Huntsville', 'Triangle'),
#   (('5/25/05', '02:45'), 'Montgomery', 'Triangle'),
#   (('5/23/05', '12:00'), 'Orange Beach', 'Light'),
#   (('5/21/05', '13:00'), 'Dadeville', 'Circle'),
#   (('4/19/05', '01:00'), 'Montgomery', 'Changing'),
#   (('3/15/05', '20:00'), 'Hanceville', 'Triangle'),
#   (('3/11/05', '20:00'), 'Headland', 'Light'),
#   (('2/18/05', '16:30'), 'Cullman', 'Fireball'),
#   (('1/15/05', '23:50'), 'Birmingham', 'Triangle'),
#   (('1/5/05', '14:15'), 'Cullman', 'Triangle'),
#   (('12/16/04', '22:40'), 'Gaylesville', 'Rectangle'),
#   (('11/27/04', '19:35'), 'Clanton', 'Light'),
#   (('11/12/04', '20:00'), 'Dothan', 'Light'),
#   (('10/4/04', '05:30'), 'Montgomery', 'Light'),
#   (('10/2/04', '19:30'), 'Orange Beach', 'Light'),
#   (('9/12/04', '21:00'), 'Attalla/Gadsden', 'Triangle'),
#   (('8/19/04', '22:15'), 'Orange Beach', 'Circle'),
#   (('8/16/04', '19:00'), 'Gulf Shores', 'Triangle'),
#   (('8/6/04', '22:15'), 'Huntsville', 'Light'),
#   (('7/25/04', '14:50'), 'Huntsville', 'Triangle'),
#   (('6/8/04', '00:40'), 'Birmingham', 'Circle'),
#   (('5/23/04', '23:00'), 'Hanceville', 'Oval'),
#   (('5/3/04', '21:26'), 'Helena', 'Chevron'),
#   (('4/30/04', '21:00'), 'Gadsden', 'Cigar'),
#   (('4/16/04', '12:00'), 'Orange Beach', 'Sphere'),
#   (('4/15/04', '01:30'), 'Tuscaloosa', 'Other'),
#   (('4/5/04', '23:30'), 'Leeds', 'Light'),
#   (('3/6/04', '15:30'), 'Foley', 'Sphere'),
#   (('2/22/04', '21:05'), 'Hartselle', 'Fireball'),
#   (('2/20/04', '02:00'), 'Silverhill (SE of)', 'Light'),
#   (('2/1/04', '02:00'), 'Birmingham', 'Chevron'),
#   (('1/10/04', '19:30'), 'Rock Creek', 'Diamond'),
#   (('12/23/03', '05:11'), 'Hayneville', 'Light'),
#   (('11/22/03', '09:20'), 'Florence', 'Triangle'),
#   (('11/19/03', '22:30'), 'Birmingham', 'Light'),
#   (('11/16/03', '23:32'), 'Enterprise', 'Light'),
#   (('11/15/03', '22:00'), 'Athens', 'Triangle'),
#   (('11/11/03', '18:00'), 'Hueytown', 'Other'),
#   (('11/10/03', '23:50'), 'Tuscaloosa', 'Cone'),
#   (('11/7/03', '16:00'), 'Oxford', 'Cylinder'),
#   (('11/3/03', '15:20'), 'Holly Pond', 'Oval'),
#   (('11/3/03', '11:45'), 'Mobile', 'Triangle'),
#   (('11/3/03', '00:00'), 'Morris', 'Diamond'),
#   (('11/1/03', '20:11'), 'Wind Creek State Park', 'Light'),
#   (('10/24/03', '23:45'), 'Mobile', 'Triangle'),
#   (('10/18/03', '19:00'), 'Tuscumbia/Cherokee (between)', 'Other'),
#   (('10/17/03', '20:45'), 'Opp', 'Triangle'),
#   (('10/2/03', '19:30'), 'Mobile', 'Chevron'),
#   (('9/25/03', '20:30'), 'Dothan', 'Light'),
#   (('9/16/03', '20:15'), 'Elba', 'Light'),
#   (('7/30/03', '19:00'), 'Birmingham', 'Rectangle'),
#   (('7/16/03', '16:00'), 'Crossville', 'Triangle'),
#   (('7/7/03', '17:30'), 'Jasper', 'Fireball'),
#   (('7/5/03', '19:40'), 'Athens', 'Cylinder'),
#   (('6/30/03', '14:00'), 'Birmingham', 'Cylinder'),
#   (('6/15/03', '04:30'), 'Alabama (rural)', 'Sphere'),
#   (('6/13/03', '00:18'), 'Birmingham', 'Disk'),
#   (('6/4/03', '22:53'), 'Huntsville', 'Disk'),
#   (('6/1/03', '23:15'), 'Jasper', 'Oval'),
#   (('6/1/03', '22:30'), 'Cullman', 'Oval'),
#   (('6/1/03', '22:30'), 'Cullman', 'Oval'),
#   (('6/1/03', '22:30'), 'Cullman', 'Oval'),
#   (('6/1/03', '22:00'), 'Ardmore', 'Oval'),
#   (('2/13/03', '14:00'), 'Hillsboro', 'Other'),
#   (('2/2/03', '20:08'), 'Auburn', 'Egg'),
#   (('1/26/03', '19:00'), 'Chickasaw', 'Other'),
#   (('1/18/03', '02:30'), 'Moundville', 'Changing'),
#   (('1/16/03', '00:30'), 'Boaz', 'Circle'),
#   (('1/10/03', '22:00'), 'Cullman', 'Diamond'),
#   (('1/6/03', '04:00'), 'Moundville', 'Egg'),
#   (('12/15/02', '00:00'), 'Maylene', 'Light'),
#   (('12/14/02', '15:45'), 'Irvington', 'Light'),
#   (('11/26/02', '22:10'), 'Madison', 'Light'),
#   (('11/8/02', '20:10'), 'Mobile', 'Chevron'),
#   (('11/7/02', '18:30'), 'Enterprise', 'Chevron'),
#   (('9/7/02', '23:15'), 'Guntersville', 'Other'),
#   (('8/2/02', '22:15'), 'Hazel Green', 'Triangle'),
#   (('7/18/02', '21:30'), 'Hoover', 'Light'),
#   (('7/17/02', '02:30'), 'Jacksonville', 'Circle'),
#   (('6/6/02', '21:34'), 'Elberta', 'Light'),
#   (('5/6/02', '20:40'), 'Union Grove', 'Circle'),
#   (('4/25/02', '22:15'), 'Stockton', 'Triangle'),
#   (('2/24/02', '16:00'), 'Marion County', 'Other'),
#   (('2/19/02', '17:00'), 'Mobile', 'Triangle'),
#   (('11/18/01', '04:30'), 'Foley', 'Other'),
#   (('9/5/01', '20:45'), 'Guntersville', 'Light'),
#   (('8/1/01', '21:10'), 'Wetumpka', 'Light'),
#   (('6/23/01', '20:47'), 'Helena', 'Fireball'),
#   (('5/29/01', '21:30'), 'Fyffe', 'Oval'),
#   (('5/18/01', '21:20'), 'Hoover', 'Triangle'),
#   (('5/10/01', '00:00'), 'Bear Creek', 'Fireball'),
#   (('4/26/01', '20:50'), 'Madison', 'Flash'),
#   (('4/19/01', '20:30'), 'Hamilton', 'Other'),
#   (('3/1/01', '23:00'), 'Madison', 'Circle'),
#   (('2/18/01', '18:25'), 'Irvington', 'Light'),
#   (('11/21/00', '05:07'), 'Warrior', 'Light'),
#   (('10/31/00', '20:00'), 'Sipsey', 'Disk'),
#   (('10/15/00', '03:00'), 'Alabama', 'Sphere'),
#   (('10/5/00', '21:05'), 'Daphne', 'Circle'),
#   (('9/18/00', '19:00'), 'Cullman', 'Light'),
#   (('9/15/00', '21:00'), 'Ozark', 'Light'),
#   (('9/14/00', '21:00'), 'Homewood', 'Egg'),
#   (('7/18/00', '11:35'), 'Huntsville', 'Circle'),
#   (('5/30/00', '21:00'), 'Fort Morgan', 'Oval'),
#   (('4/22/00', '22:00'), 'Birmingham', 'Changing'),
#   (('4/19/00', '19:10'), 'Alabaster', 'Egg'),
#   (('3/28/00', '21:15'), 'Fort. Deposit', 'Triangle'),
#   (('3/22/00', '21:40'), 'Tuscaloosa', 'Formation'),
#   (('3/11/00', '12:30'), 'Mobile', 'Triangle'),
#   (('2/1/00', '02:30'), 'Lynn', 'Triangle'),
#   (('1/7/00', '23:00'), 'Montgomery', 'Triangle'),
#   (('12/31/99', '01:00'), 'Boaz', 'Cigar'),
#   (('12/5/99', '04:25'), 'Sterrett (15 miles south of Birmingham)', 'Disk'),
#   (('12/5/99', '04:20'), 'Weogufka', 'Fireball'),
#   (('12/5/99', '04:20'), 'Birmingham', 'Sphere'),
#   (('12/5/99', '04:20'), 'Colombiana', 'Rectangle'),
#   (('11/3/99', '21:00'), 'Leighton (La Grange Mountain)', 'Triangle'),
#   (('10/29/99', '17:45'), 'Tuscaloosa', 'Circle'),
#   (('10/11/99', '00:15'), 'Montgomery', 'Light'),
#   (('9/10/99', '14:05'), 'Gardendale', 'Other'),
#   (('7/26/99', '21:00'), 'Leeds (outside Birmingham)', 'Sphere'),
#   (('7/16/99', '00:00'), 'Birmingham', 'Sphere'),
#   (('7/4/99', '21:30'), 'Northport', 'Light'),
#   (('7/2/99', '11:30'), 'Troy', 'Cigar'),
#   (('7/1/99', '19:00'), 'Birmingham', 'Flash'),
#   (('6/25/99', '22:23'), 'Huntsville', 'Oval'),
#   (('6/15/99', '23:30'), 'Jasper', 'Circle'),
#   (('6/5/99', '23:45'), 'Huntsville', 'Flash'),
#   (('5/11/99', '23:40'), 'Tarrant (Robinwood)', 'Triangle'),
#   (('5/8/99', '23:40'), 'Tarrant (Robinwood)', 'Triangle'),
#   (('4/15/99', '19:00'), 'Fyffe', 'Rectangle'),
#   (('4/5/99', '15:00'), 'Huntsville', 'Cigar'),
#   (('3/15/99', '20:40'), 'Atmore', 'Light'),
#   (('3/7/99', '22:00'), 'Arab', 'Light'),
#   (('2/10/99', '20:15'), 'Huntsville', 'Light'),
#   (('1/27/99', '18:04'), 'Mobile', 'Light'),
#   (('1/25/99', '17:40'), 'Alabaster', 'Fireball'),
#   (('1/15/99', '13:00'), 'Montgomery', 'Sphere'),
#   (('1/1/99', '21:00'), 'Cheaha Mountain', 'Triangle'),
#   (('12/17/98', '07:10'), 'Decatur', 'Changing'),
#   (('12/15/98', '09:25'), 'Arab', 'Sphere'),
#   (('11/25/98', '21:24'), 'Gulf Shores', 'Flash'),
#   (('10/20/98', '22:00'), 'Huntsville', 'Triangle'),
#   (('10/15/98', '22:30'), 'Adamsville', 'Circle'),
#   (('10/15/98', '21:00'), 'Enterprise', 'Triangle'),
#   (('8/28/98', '05:45'), 'Mobile', 'Light'),
#   (('8/18/98', '21:15'), 'Silverhill', 'Disk'),
#   (('7/22/98', '17:43'), 'Athens', 'Disk'),
#   (('7/12/98', '20:00'), 'Decatur', 'Other'),
#   (('7/4/98', '23:00'), 'Huntsville', 'Light'),
#   (('7/3/98', '21:30'), 'Huntsville', 'Light'),
#   (('6/1/98', '18:00'), 'Hunstville', 'Changing'),
#   (('2/12/98', '12:35'), 'Shelby County airport (@231 mile marker)', 'Cigar'),
#   (('8/15/97', '01:00'), 'Grand Bay', 'Triangle'),
#   (('7/14/97', '14:30'), 'Gulf Shores', 'Circle'),
#   (('6/27/97', '21:00'), 'Gulf Shores', 'Triangle'),
#   (('5/10/97', '21:00'), 'Southside (Gadsden)', 'Other'),
#   (('4/23/97', '18:00'), 'Guntersville', 'Oval'),
#   (('4/5/97', '14:00'), 'Fairhope', 'Circle'),
#   (('4/5/97', '14:00'), 'Fairhope', 'Other'),
#   (('3/20/97', '01:00'), 'Demopolis', 'Disk'),
#   (('2/26/97', '20:00'), 'Mobile', 'Oval'),
#   (('9/15/96', '21:00'), 'Woodville', 'Triangle'),
#   (('9/1/96', '17:00'), 'Tuscaloosa', 'Disk'),
#   (('6/18/96', '17:30'), 'Alabama (location unspecified)', 'Fireball'),
#   (('4/22/96', '17:00'), 'Gunteersville', 'Circle'),
#   (('4/2/96', '13:00'), 'Muscle Shoals', 'Other'),
#   (('1/31/96', '02:00'),
#    'Heflin  (Talladega National Forest at Oak Level)',
#    'Light'),
#   (('1/15/96', '22:00'), 'Birmingham (Huffman/Centerpoint)', 'Teardrop'),
#   (('12/24/95', '22:00'),
#    'Centreville/Selma (area on state road 219 between)',
#    'Fireball'),
#   (('12/23/95', '17:30'), 'Mobile', 'Other'),
#   (('11/1/95', '22:30'), 'Daphne', 'Triangle'),
#   (('8/25/95', '01:00'), 'Morris', 'Other'),
#   (('7/1/95', '19:00'), 'Wedowee', 'Sphere'),
#   (('5/27/95', '17:30'), 'Southside', 'Circle'),
#   (('3/19/95', '19:30'), 'Mobile', 'Disk'),
#   (('11/12/94', '12:00'), 'St. Florian', 'Disk'),
#   (('10/15/94', '20:00'), 'Birmingham', 'Triangle'),
#   (('8/4/94', '22:00'), 'Opp', 'Circle'),
#   (('6/30/94', '23:45'), 'Weogufka', 'Light'),
#   (('6/15/94', '22:00'), 'Montgomery', 'Triangle'),
#   (('6/1/94', '22:00'), 'Montgomery', 'Triangle'),
#   (('6/1/94', '21:00'), 'Montgomery', 'Triangle'),
#   (('6/1/94', '17:00'), 'Montgomery', 'Rectangle'),
#   (('3/15/94', '14:00'), 'Columbus City', 'Cylinder'),
#   (('6/15/93', '21:00'), 'Salem', 'Triangle'),
#   (('1/20/93', '21:00'), 'New Hope', 'Triangle'),
#   (('9/23/92', '02:34'), 'Wetumpka', 'Triangle'),
#   (('8/18/92', '17:00'), 'Wagarville', 'Fireball'),
#   (('6/6/92', '20:00'), 'Leesburg', 'Light'),
#   (('3/15/92', '15:00'), 'Hanceville', 'Disk'),
#   (('5/7/89', '11:50'), 'Talladega (Super Speedway)', 'Rectangle'),
#   (('2/15/88', '21:00'), 'Huntsville', 'Other'),
#   (('2/15/88', '02:30'), 'Indian Springs', 'Oval'),
#   (('12/12/87', '23:00'), 'Aliceville', 'Formation'),
#   (('7/15/87', '22:30'), 'Collinsville', 'Triangle'),
#   (('10/15/86', '14:00'), 'Pinson', 'Circle'),
#   (('12/5/85', '05:00'), 'Manaus-Amazonas (Brazil)', 'Egg'),
#   (('8/16/85', '19:00'), 'Columbia', 'Other'),
#   (('5/1/85', '20:30'), 'Lanett', 'Light'),
#   (('10/31/84', '22:00'), 'Vincent', 'Circle'),
#   (('7/1/84', '16:00'), 'Montevallo', 'Circle'),
#   (('6/1/84', '17:15'), 'Mobile', 'Sphere'),
#   (('10/15/80', '03:00'), 'Guntersville', 'Triangle'),
#   (('10/1/80', '20:00'), 'Mountainboro', 'Fireball'),
#   (('6/30/80', '21:00'), 'Montgomery', 'Disk'),
#   (('6/1/80', '21:00'), 'Birmingham', 'Triangle'),
#   (('6/1/80', '16:00'), 'Montgomery', 'Disk'),
#   (('9/17/79', '18:15'), 'Mobile', 'Rectangle'),
#   (('6/14/79', '20:00'), 'Wagarville', 'Cigar'),
#   (('10/18/78', '23:30'), 'Birmingham', 'Oval'),
#   (('8/15/78', '19:30'), 'Carbon Hill', 'Triangle'),
#   (('8/15/78', '15:30'), 'Gadsden', 'Sphere'),
#   (('7/20/78', '00:00'), 'Tuskegee', 'Circle'),
#   (('7/7/78', '13:00'), 'Ardmore (near)', 'Sphere'),
#   (('7/1/78', '23:00'), 'Lake Martin', 'Oval'),
#   (('8/15/77', '23:00'), 'Interstate 65 (Alabama/Tennessee)', 'Light'),
#   (('7/1/77', '12:00'), 'Anniston (Ft. McClellan U.S. Army base)', 'Disk'),
#   (('6/16/77', '22:00'), 'Interstate 65 (between AL and TN)', 'Light'),
#   (('8/15/76', '18:00'), 'Birmingham', 'Disk'),
#   (('7/1/76', '22:00'), 'Gadsden', 'Disk'),
#   (('6/15/76', '21:00'), 'Elba', 'Cigar'),
#   (('5/1/76', '17:30'), 'Birmingham', 'Triangle'),
#   (('10/15/75', '23:00'), 'Collinsville', 'Triangle'),
#   (('10/15/75', '18:30'), 'Anniston', 'Circle'),
#   (('9/4/75', '02:00'), 'Union Grove', 'Cigar'),
#   (('7/15/75', '17:00'), 'Birmingham', 'Disk'),
#   (('11/25/74', '22:00'), 'Verbena', 'Sphere'),
#   (('10/22/74', '20:00'), 'Oneonta', 'Circle'),
#   (('9/1/74', '20:00'), 'Auburn/Montgomery (between)', 'Rectangle'),
#   (('6/15/74', '22:30'), 'Calera (outskirts of)', 'Disk'),
#   (('4/2/74', '23:30'), 'Birmingham (Wisteria Dr., .5 mi down)', 'Disk'),
#   (('11/15/73', '18:00'), 'Colbert Heights', 'Disk'),
#   (('10/17/73', '23:30'), 'Montgomery', 'Light'),
#   (('10/12/73', '19:00'), 'Birmingham (just south of)', 'Disk'),
#   (('6/15/73', '22:30'), 'Calera (out-skirts)', 'Disk'),
#   (('6/15/73', '21:00'), 'Decatur', 'Circle'),
#   (('6/15/73', '15:30'), 'Bridgeport', 'Disk'),
#   (('5/21/73', '20:00'), 'Huntsville', 'Cylinder'),
#   (('5/19/73', '20:10'), 'Huntsville (Redstone Arsenal)', 'Disk'),
#   (('5/14/73', '20:00'), 'Madison', 'Disk'),
#   (('2/10/73', '02:00'), 'Moundville', 'Cigar'),
#   (('2/3/73', '16:00'), 'Fort Rucker', 'Light'),
#   (('1/8/73', '21:00'), 'Muscle Shoals', 'Oval'),
#   (('11/1/72', '00:00'), '?', 'Light'),
#   (('10/29/72', '15:30'), 'Monroeville', 'Cylinder'),
#   (('8/25/72', '08:30'), 'Coldwater', 'Triangle'),
#   (('8/12/72', '10:00'), 'Auburn', 'Circle'),
#   (('6/15/72', '20:30'), 'Union Grove', 'Formation'),
#   (('5/1/71', '19:00'), 'Cherokee', 'Light'),
#   (('4/5/71', '19:00'), 'Talladega', 'Disk'),
#   (('3/30/70', '21:00'), 'Slocomb', 'Circle'),
#   (('1/1/70', '13:00'), 'Telford', 'Oval'),
#   (('7/15/69', '22:00'), 'North Atlantic Ocean', 'Light'),
# ...
#   (('10/28/11', '19:18'), 'Menomonie', 'Sphere'),
#   (('10/28/11', '06:00'), 'Alma Center', 'Light'),
#   (('10/27/11', '23:30'), 'Madison', 'Triangle'),
#   (('10/27/11', '22:00'), 'Marshfield', 'Triangle'),
#   (('10/23/11', '22:15'), 'Mukwonago', 'Triangle'),
#   (('10/22/11', '03:15'), 'Wausau', 'Oval'),
#   (('10/21/11', '07:35'), 'Granton', 'Light'),
#   (('10/9/11', '22:56'), 'River Falls', 'Fireball'),
#   (('10/9/11', '18:15'), 'Waukesha', 'Disk'),
#   (('10/8/11', '22:00'), 'Wisconsin Dells', 'Sphere'),
#   (('10/7/11', '21:35'), 'Lake Geneva', 'Sphere'),
#   (('9/30/11', '20:00'), 'New Berlin', 'Triangle'),
#   (('9/24/11', '00:00'), 'Kimball', 'Diamond'),
#   ...],
#  'WY': [(('5/3/21', '22:30'), 'Point of Rocks', 'Light'),
#   (('4/27/21', '09:20'), 'Douglas', 'Light'),
#   (('12/4/20', '19:05'), 'Riverton', 'Light'),
#   (('12/4/20', '17:46'), 'Laramie', 'Formation'),
#   (('11/30/20', '12:00'), 'Unknown', 'Other'),
#   (('11/13/20', '17:30'), 'Sheridan', 'Other'),
#   (('9/20/20', '15:30'), 'Riverton', 'Sphere'),
#   (('9/5/20', '11:35'), 'Evanston', 'Formation'),
#   (('9/2/20', '19:39'), 'Cheyenne', 'Other'),
#   (('8/13/20', '18:57'), 'Centennial', 'Oval'),
#   (('8/7/20', '04:10'), 'Shell', 'Cylinder'),
#   (('8/3/20', '03:59'), 'Moran', 'Diamond'),
#   (('7/3/20', '23:00'), 'Casper', 'Diamond'),
#   (('6/11/20', '21:48'), 'Sheridan', 'Light'),
#   (('5/30/20', '22:30'), 'Casper', 'Sphere'),
#   (('4/17/20', '21:30'), 'Riverton', 'Circle'),
#   (('4/17/20', '21:00'), 'Shoshoni', 'Light'),
#   (('4/17/20', '20:05'), 'Sheridan', 'Sphere'),
#   (('3/26/20', '21:15'), 'Jackson', 'Formation'),
#   (('3/25/20', '21:00'), 'Cheyenne', 'Light'),
#   (('3/24/20', '21:13'), 'Laramie', 'Triangle'),
#   (('3/6/20', '20:20'), 'Hoback', 'Light'),
#   (('1/16/20', '07:35'), 'Big Horn Mountains', 'Formation'),
#   (('12/31/19', '05:25'), 'Casper', 'Formation'),
#   (('12/24/19', '19:21'), 'Clark', 'Light'),
#   (('12/24/19', '18:00'), 'Greybull', 'Light'),
#   (('10/27/19', '20:00'), 'Cody', 'Disk'),
#   (('10/25/19', '08:00'), 'Bar Nunn', 'Circle'),
#   (('10/22/19', '19:27'), 'Cheyenne', 'Light'),
#   (('8/31/19', '08:00'), 'Alpine', 'Egg'),
#   (('8/3/19', '19:00'), 'Wapiti', 'Oval'),
#   (('7/28/19', '22:30'), 'Rawlins', 'Light'),
#   (('6/17/19', '22:30'), 'Casper', 'Triangle'),
#   (('6/17/19', '22:30'), 'Casper', 'Triangle'),
#   (('6/5/19', '20:30'), 'Gillette', 'Other'),
#   (('5/28/19', '22:30'),
#    'Yellowstone National Park (Canyon Village, west of)',
#    'Circle'),
#   (('5/26/19', '00:00'), 'Hulett', 'Light'),
#   (('4/21/19', '05:30'), 'Teton Village', 'Oval'),
#   (('3/4/19', '22:08'), 'Cheyenne', 'Triangle'),
#   (('2/6/19', '18:30'), 'Riverton', 'Sphere'),
#   (('1/8/19', '03:00'), 'Fontenelle', 'Sphere'),
#   (('12/24/18', '18:35'), 'Riverton', 'Formation'),
#   (('11/11/18', '17:58'), 'Evanston', 'Circle'),
#   (('9/2/18', '22:20'), 'Cheyenne', 'Formation'),
#   (('8/14/18', '20:15'), 'Glenrock', 'Sphere'),
#   (('5/15/18', '03:30'), 'Jackson Hole', 'Sphere'),
#   (('5/11/18', '01:00'), 'Glendo (15 miles S of; I-25)', 'Triangle'),
#   (('4/23/18', '22:00'), 'Cody', 'Light'),
#   (('2/21/18', '03:45'), 'Big Horn', 'Flash'),
#   (('2/16/18', '01:15'), 'Cheyenne', 'Light'),
#   (('1/19/18', '19:15'), 'Cheyenne', 'Sphere'),
#   (('1/4/18', '19:00'), 'Riverton', 'Sphere'),
#   (('1/4/18', '13:00'), 'In-flight sighting', 'Oval'),
#   (('12/28/17', '03:00'), 'Cheyenne', 'Changing'),
#   (('12/14/17', '19:50'), 'Lusk', 'Fireball'),
#   (('12/9/17', '20:30'), 'Powell', 'Formation'),
#   (('12/9/17', '20:30'),
#    'Shoshoni (outside of; towards Riverton)',
#    'Formation'),
#   (('12/9/17', '16:45'), 'Cheyenne', 'Circle'),
#   (('11/25/17', '00:00'), 'Lander', 'Light'),
#   (('10/28/17', '20:00'), 'Cody and Wapiti (between)', 'Fireball'),
#   (('10/15/17', '20:15'), 'Douglas', 'Sphere'),
#   (('7/26/17', '21:50'), 'Buffalo', 'Circle'),
#   (('7/17/17', '21:00'), 'Cody', 'Cylinder'),
#   (('6/1/17', '11:00'), 'Buford', 'Sphere'),
#   (('2/26/17', '20:06'), 'Cody', 'Fireball'),
#   (('2/18/17', '20:45'), 'Buford', 'Circle'),
#   (('2/18/17', '20:45'), 'Buford', 'Circle'),
#   (('1/1/17', '01:15'), 'Cody', 'Fireball'),
#   (('11/30/16', '21:00'), 'Riverton (outside of)', 'Circle'),
#   (('11/10/16', '23:00'), 'Casper', 'Chevron'),
#   (('10/19/16', '20:30'), 'Rawlins', 'Light'),
#   (('10/10/16', '01:20'), 'Lovell', 'Triangle'),
#   (('10/1/16', '19:30'), 'Glenrock', 'Disk'),
#   (('10/1/16', '06:00'), 'Recluse', 'Light'),
#   (('9/10/16', '21:25'), 'Cheyenne', 'Other'),
#   (('9/4/16', '09:30'), 'Buffalo', 'Rectangle'),
#   (('8/29/16', '09:30'), 'Cody', 'Other'),
#   (('8/21/16', '10:58'), 'Gillette', 'Circle'),
#   (('8/14/16', '16:30'), 'Saratoga', 'Sphere'),
#   (('8/8/16', '22:15'), 'Sheridan', 'Fireball'),
#   (('7/30/16', '20:00'), 'Veduawoo', 'Sphere'),
#   (('7/26/16', '21:05'), 'Sheridan', 'Circle'),
#   (('3/19/16', '01:30'), 'Cody', 'Other'),
#   (('1/1/16', '00:30'), 'Thermopolis', 'Triangle'),
#   (('10/18/15', '21:15'), 'Cody', 'Triangle'),
#   (('10/13/15', '22:35'), 'Rock Springs', 'Formation'),
#   (('9/12/15', '21:45'), 'Cheyenne', 'Formation'),
#   (('8/5/15', '20:25'), 'Torrington', 'Sphere'),
#   (('8/4/15', '22:30'), 'Torrington', 'Sphere'),
#   (('8/3/15', '22:10'), 'Casper', 'Cigar'),
#   (('8/1/15', '22:00'), 'Torrington', 'Sphere'),
#   (('8/1/15', '02:30'), 'Evanston', 'Oval'),
#   (('7/26/15', '21:45'), 'Beloit', 'Fireball'),
#   (('6/19/15', '22:00'), 'Laramie', 'Light'),
#   (('6/18/15', '22:30'), 'Torrington', 'Sphere'),
#   (('6/11/15', '10:30'), 'Casper', 'Light'),
#   (('5/28/15', '21:00'), 'Cheyenne', 'Light'),
#   (('5/15/15', '13:00'), 'Cheyenne', 'Circle'),
#   (('4/29/15', '19:15'), 'Chugwater', 'Other'),
#   (('4/25/15', '14:00'), 'Lander', 'Disk'),
#   (('1/31/15', '19:25'), 'Evanston', 'Light'),
#   (('1/1/15', '06:30'), 'Rozet', 'Sphere'),
#   (('12/1/14', '10:00'), 'Sheridan', 'Other'),
#   (('10/23/14', '01:30'), 'GreenRiver', 'Triangle'),
#   (('10/18/14', '21:15'), 'Cody', 'Triangle'),
#   (('10/3/14', '17:00'), 'Ehete', 'Circle'),
#   (('8/19/14', '07:40'), 'Yellowstone National Park', 'Teardrop'),
#   (('8/16/14', '17:05'), 'Cheyenne', 'Triangle'),
#   (('8/12/14', '22:15'), 'Dubois', 'Other'),
#   (('8/12/14', '22:00'), 'Dubois', 'Light'),
#   (('8/11/14', '19:45'), 'Evanston', 'Cone'),
#   (('7/26/14', '23:10'), 'Cheyenne', 'Triangle'),
#   (('7/9/14', '13:00'), 'Dubois (South of; on Hwy 26)', 'Cylinder'),
#   (('5/25/14', '20:00'), 'Rock Springs (35 miles north of)', 'Light'),
#   (('5/24/14', '22:00'), 'Rock Springs', 'Light'),
#   (('4/17/14', '18:00'), 'Yellowstone North Entrance', 'Circle'),
#   (('4/15/14', '23:00'), 'Thermopolis', 'Triangle'),
#   (('2/25/14', '18:35'), 'Evanston', 'Light'),
#   (('2/25/14', '02:20'), 'Casper', 'Circle'),
#   (('1/23/14', '23:00'), 'Fort Washakie', 'Light'),
#   (('12/11/13', '18:25'), 'Powell', 'Chevron'),
#   (('12/9/13', '18:30'), 'Buffalo', 'Light'),
#   (('12/7/13', '01:00'), 'Laramie', 'Sphere'),
#   (('11/7/13', '01:45'), 'Casper', 'Chevron'),
#   (('10/23/13', '21:15'), 'Alcova', 'Light'),
#   (('9/11/13', '09:00'), 'Gillette', 'Circle'),
#   (('8/12/13', '21:30'), "Devil's Tower", 'Light'),
#   (('8/4/13', '22:00'), 'Yellowstone', 'Light'),
#   (('7/29/13', '01:30'), 'Casper', 'Triangle'),
#   (('7/11/13', '23:00'), 'Meeteetse', 'Light'),
#   (('7/1/13', '01:00'), 'Casper', 'Triangle'),
#   (('5/29/13', '23:37'), 'Cody', 'Light'),
#   (('5/2/13', '19:45'), 'Gillette', 'Light'),
#   (('4/5/13', '21:00'), 'Rock Springs', 'Other'),
#   (('2/14/13', '06:00'), 'Point of Rocks', 'Circle'),
#   (('12/7/12', '06:30'), 'Rock Springs', 'Disk'),
#   (('11/7/12', '19:30'), 'Casper', 'Sphere'),
#   (('9/22/12', '02:30'), 'Gillette', 'Other'),
#   (('8/25/12', '21:15'), 'Rock Springs', 'Light'),
#   (('8/23/12', '21:30'), 'Casper', 'Light'),
#   (('8/22/12', '22:00'), 'Rock Springs', 'Sphere'),
#   (('8/7/12', '22:20'), 'Sheridan', 'Light'),
#   (('6/20/12', '16:00'), 'Laramie', 'Circle'),
#   (('6/20/12', '12:42'), 'Bill', 'Light'),
#   (('6/6/12', '21:45'), 'Jackson Hole', 'Fireball'),
#   (('3/17/12', '12:30'), 'Pine Haven', 'Teardrop'),
#   (('3/12/12', '01:02'), 'Rock Springs', 'Chevron'),
#   (('12/15/11', '17:30'), 'Laramie', 'Changing'),
#   (('11/14/11', '18:50'), 'Green River', 'Triangle'),
#   (('10/31/11', '20:15'), 'Rock Springs', 'Sphere'),
#   (('10/21/11', '19:30'), 'Hulett (near)', 'Light'),
#   (('9/20/11', '19:55'), 'Yellowstone National Park', 'Changing'),
#   (('9/18/11', '21:00'), 'La Barge', 'Circle'),
#   (('9/12/11', '20:30'), 'Casper', 'Circle'),
#   (('8/31/11', '00:00'), 'Rock Springs', 'Light'),
#   (('8/20/11', '23:00'), 'Casper', 'Light'),
#   (('8/5/11', '18:13'), 'Cheyenne', 'Circle'),
#   (('7/23/11', '23:00'), 'Jackson Hole', 'Triangle'),
#   (('7/20/11', '22:13'), 'Casper', 'Light'),
#   (('6/25/11', '23:30'), 'Yellowstone National Park', 'Flash'),
#   (('6/16/11', '23:30'), 'Green River', 'Sphere'),
#   (('6/3/11', '15:00'), 'Mills', 'Circle'),
#   (('4/1/11', '21:10'), 'Cheyenne', 'Light'),
#   (('2/22/11', '18:00'), 'Cody', 'Light'),
#   (('2/21/11', '19:00'), 'Glenrock', 'Light'),
#   (('2/15/11', '20:00'), 'Yellowstone National Park', 'Light'),
#   (('1/17/11', '20:00'), 'Casper', 'Sphere'),
#   (('12/17/10', '18:15'), 'Buffalo', 'Disk'),
#   (('12/13/10', '18:24'), 'Gillette', 'Fireball'),
#   (('10/15/10', '02:30'), 'Cheyenne', 'Light'),
#   (('9/13/10', '21:30'), 'Rock Springs', 'Light'),
#   (('8/29/10', '21:20'), 'Cokeville', 'Formation'),
#   (('8/6/10', '00:30'), 'Cheyenne', 'Other'),
#   (('7/15/10', '02:00'), 'Teton National Park', 'Circle'),
#   (('6/6/10', '02:45'), 'Gillette', 'Light'),
#   (('4/30/10', '21:30'), 'Evansville', 'Circle'),
#   (('4/29/10', '20:45'), 'Cheyenne', 'Light'),
#   (('9/23/09', '04:30'), 'Cheyenne', 'Oval'),
#   (('7/21/09', '22:15'), 'Laramie', 'Circle'),
#   (('7/8/09', '04:25'), 'Powell', 'Circle'),
#   (('12/21/08', '17:00'), 'Laramie/Wamsutter (between)', 'Flash'),
#   (('10/25/08', '21:00'), 'Rock Springs', 'Other'),
#   (('10/23/08', '04:45'), '((Location unspecified; rural area))', 'Flash'),
#   (('10/7/08', '20:00'), 'Lyman', 'Flash'),
#   (('9/26/08', '23:25'), 'Cheyenne', 'Triangle'),
#   (('8/11/08', '20:15'), 'Gillette', 'Egg'),
#   (('7/19/08', '12:00'), 'Teton National Park', 'Oval'),
#   (('4/1/08', '21:00'), 'Clark', 'Disk'),
#   (('2/15/08', '05:00'), 'Worland', 'Oval'),
#   (('11/4/07', '00:40'), 'Powell', 'Triangle'),
#   (('9/30/07', '18:30'), 'Laramie', 'Other'),
#   (('9/2/07', '22:30'), 'Casper', 'Light'),
#   (('6/24/07', '00:30'), 'Douglas', 'Light'),
#   (('6/21/07', '23:00'), 'Evanston', 'Formation'),
#   (('6/19/07', '23:00'), 'Yellowstone National Park', 'Formation'),
#   (('11/7/06', '21:00'), 'Laramie', 'Rectangle'),
#   (('10/13/06', '20:30'), 'Rawlins', 'Triangle'),
#   (('8/23/06', '21:55'), 'Clark', 'Light'),
#   (('8/13/06', '22:20'), 'Riverton', 'Formation'),
#   (('7/18/06', '02:30'), 'Big Sandy', 'Light'),
#   (('6/28/06', '22:00'), 'Casper', 'Light'),
#   (('6/6/06', '04:15'), 'Pinedale', 'Circle'),
#   (('4/30/06', '16:00'), 'Bear River/Evanston', 'Sphere'),
#   (('3/15/06', '23:30'), 'Shirley Basin Road', 'Light'),
#   (('12/11/05', '21:15'), 'Fox Park', 'Sphere'),
#   (('11/5/05', '23:28'), 'Laramie', 'Light'),
#   (('9/28/05', '16:30'), 'Wyoming (I-80, westbound)', 'Other'),
#   (('8/7/05', '03:45'), 'Medicine Bow', 'Light'),
#   (('7/31/05', '04:20'), 'Clark', 'Light'),
#   (('6/6/05', '15:52'), 'Casper', 'Rectangle'),
#   (('5/19/05', '18:45'), 'Cheyenne', 'Oval'),
#   (('10/28/04', '02:00'), 'Sheridan', 'Light'),
#   (('4/30/04', '04:30'), 'Casper', 'Cylinder'),
#   (('3/19/04', '23:15'), 'Cheyenne', 'Other'),
#   (('2/16/04', '11:30'), 'Lander', 'Diamond'),
#   (('2/14/04', '22:25'), 'Casper', 'Triangle'),
#   (('11/1/03', '00:00'), 'Cheyenne', 'Fireball'),
#   (('10/27/03', '18:00'), 'Farson', 'Cylinder'),
#   (('10/3/03', '20:51'), 'Clark', 'Light'),
#   (('9/29/03', '20:35'), 'Yellowstone National Park', 'Sphere'),
#   (('9/19/03', '14:00'), 'na', 'Teardrop'),
#   (('7/17/03', '23:30'), 'Jackson', 'Light'),
#   (('6/17/03', '22:42'), 'Worland', 'Light'),
#   (('3/16/03', '11:00'), 'Jackson Hole', 'Chevron'),
#   (('1/8/03', '20:15'), 'Rock Springs', 'Light'),
#   (('11/28/02', '18:30'), 'Cheyenne', 'Fireball'),
#   (('10/6/02', '19:25'), 'Lander', 'Circle'),
#   (('9/28/02', '18:30'), 'Fort Bridger', 'Disk'),
#   (('9/15/02', '22:00'), 'Laramie', 'Sphere'),
#   (('9/6/02', '21:00'), 'Sheridan', 'Oval'),
#   (('9/6/02', '21:00'), 'Baggs', 'Oval'),
#   (('9/6/02', '20:30'), 'Gillette', 'Fireball'),
#   (('9/1/02', '22:00'), 'Rapid City', 'Light'),
#   (('7/15/02', '15:00'), 'Rock River (southeast of)', 'Oval'),
#   (('6/7/02', '00:30'), 'Rock Springs', 'Light'),
#   (('5/10/02', '19:00'), 'Gillette', 'Triangle'),
#   (('4/30/02', '20:15'), 'Cheyenne', 'Egg'),
#   (('4/4/02', '19:45'), 'Laramie', 'Changing'),
#   (('2/9/02', '20:30'), 'Cheyenne', 'Fireball'),
#   (('11/15/01', '21:10'), 'Clark', 'Light'),
#   (('10/28/01', '21:00'), 'Laramie', 'Fireball'),
#   (('10/24/01', '23:00'), 'Evanston', 'Oval'),
#   (('10/15/01', '03:00'), 'Chugwater', 'Light'),
#   (('8/17/01', '22:30'), 'Rock River', 'Fireball'),
#   (('8/17/01', '22:30'), 'Rock River', 'Fireball'),
#   (('8/17/01', '22:30'), 'Laramie', 'Fireball'),
#   (('8/17/01', '22:19'), 'Dubois', 'Triangle'),
#   (('8/17/01', '20:30'), 'Cheyenne', 'Other'),
#   (('7/1/01', '11:50'), 'Laramie', 'Other'),
#   (('4/25/01', '22:00'), 'Laramie', 'Light'),
#   (('3/6/01', '19:00'), 'Gillette', 'Triangle'),
#   (('1/11/01', '21:50'), 'Dubois', 'Fireball'),
#   (('1/8/01', '18:30'), 'Gillette', 'Changing'),
#   (('10/9/00', '18:45'), 'Border', 'Teardrop'),
#   (('8/13/00', '20:00'), 'Big Horn Mtns', 'Fireball'),
#   (('6/22/00', '21:00'), 'Pine Haven', 'Egg'),
#   (('6/19/00', '13:00'), 'Rawlins', 'Disk'),
#   (('6/13/00', '22:00'), 'Casper', 'Oval'),
#   (('11/23/99', '22:30'), 'Casper', 'Sphere'),
#   (('10/4/99', '17:25'), 'Gillette', 'Other'),
#   (('9/11/99', '20:00'), 'Casper', 'Triangle'),
#   (('8/15/99', '23:18'), 'Rawlins (39 miles west of)', 'Fireball'),
#   (('8/13/99', '21:50'), 'Cheyenne', 'Triangle'),
#   (('7/3/99', '21:45'),
#    'Medicine Bow National Mountains, Medicine Bow National Fores',
#    'Flash'),
#   (('7/1/99', '23:00'), 'Green River', 'Other'),
#   (('7/1/99', '22:30'), 'Buffalo', 'Cylinder'),
#   (('6/15/99', '22:00'), 'On highway; location unknown', 'Other'),
#   (('6/10/99', '23:00'), 'Riverton', 'Triangle'),
#   (('1/31/99', '19:30'), 'Riverton', 'Fireball'),
#   (('11/12/98', '02:25'), 'Casper', 'Triangle'),
#   (('9/26/98', '03:05'), 'Rock Springs', 'Fireball'),
#   (('9/24/98', '00:15'),
#    'Sheridan (10 miles South of, at the Sheridan Pipeline)',
#    'Other'),
#   (('9/5/98', '22:30'),
#    'Medicine Bow Natl. Forest (40 mi. W of Laramie)',
#    'Triangle'),
#   (('9/4/98', '15:00'), 'Cheyenne', 'Cigar'),
#   (('9/2/98', '00:30'), 'Cheyenne', 'Light'),
#   (('4/4/98', '09:00'), 'Cheyenne', 'Sphere'),
#   (('10/5/97', '19:00'), 'Cheyenne', 'Other'),
#   (('8/22/97', '23:30'), 'Atlantic City', 'Light'),
#   (('5/1/96', '22:00'), 'Cody', 'Other'),
#   (('8/15/94', '22:00'), 'Gilette', 'Fireball'),
#   (('8/15/94', '00:00'), 'Rock River', 'Disk'),
#   (('6/29/94', '23:00'),
#    'Dull Center (near Bill) (north of Douglas)',
#    'Light'),
#   (('6/15/94', '23:45'), 'Cheyenne', 'Light'),
#   (('8/23/93', '19:56'), 'Laramie (east of)', 'Changing'),
#   (('6/24/92', '22:00'), 'Laramie', 'Light'),
#   (('7/1/89', '14:00'), 'Laramie', 'Other'),
#   (('1/19/89', '20:15'), 'Laramie', 'Disk'),
#   (('1/17/89', '20:00'), 'Laramie', 'Other'),
#   (('6/7/87', '21:00'), 'Jackson Hole (Moran State Park)', 'Light'),
#   (('2/15/87', '21:00'), 'Centennial', 'Light'),
#   (('9/15/85', '23:00'), 'Green River (No. of)', 'Light'),
#   (('11/17/78', '15:00'), 'Interstate 80/25', 'Other'),
#   (('7/27/76', '01:00'), 'Cowley', 'Cylinder'),
#   (('7/25/76', '18:00'), 'Casper', 'Circle'),
#   (('7/7/75', '19:00'), 'Fort Washakie', 'Light'),
#   (('7/5/72', '01:00'), 'Powell', 'Fireball'),
#   (('6/20/70', '02:00'), 'Cheyenne', 'Circle'),
#   (('6/30/67', '03:00'), 'Lander', 'Light'),
#   (('5/1/65', '13:00'), 'Guernsey', 'Sphere'),
#   (('2/23/62', '06:15'), 'Crowheart', 'Egg'),
#   (('7/20/58', '21:30'), 'Rock Springs', 'Disk'),
#   (('7/15/56', '00:00'), 'Yellowstone Park (near South entrance)', 'Disk'),
#   (('7/3/51', '12:00'), 'Green River', 'Sphere'),
#   (('6/30/49', '23:00'), 'Little America (near)', 'Disk')]}

# %% [markdown]
# ## Additional Dataset Parsing/Cleaning Functions
#
# Write any supplemental (optional) functions here.

# %%
# this needs to be ran for the web based functions to work
def create_state_dict():
    
    # This website has a list of states and their abbreviations
    statesurl = 'https://www.ssa.gov/international/coc-docs/states.html' # source
    r = requests.get(statesurl)
    soup = BeautifulSoup(r.text, 'html.parser')
    states_list = soup.find_all('tr')
    
    # make a list of abbreviations
    abbreviations = []
    for item in states_list:
        info = item.find_all('td')
        abbreviations.append(info[1].text.strip())

    # CLEAN - Need to get rid of the wannabe states
    abbreviations.remove("AS")  # American Samoa
    abbreviations.remove("DC")  # District of Columbia
    abbreviations.remove("GU")  # Guam
    abbreviations.remove("MP")  # Northern Mariana IS
    abbreviations.remove("PR")  # Puerto Rico
    abbreviations.remove("VI")  # Virgin Islands

    # make into a dictionary 
    state_dict = {}
    for state in abbreviations:
        state_dict.update({state:{}})
    
    # export to json
    with open('state_data.json', 'w') as state_data:
        json.dump(state_dict, state_data, indent=4)
    
    return state_dict
    
############ Function Call ############
create_state_dict()
# Out:
# {'AL': {},
#  'AK': {},
#  'AZ': {},
#  'AR': {},
#  'CA': {},
#  'CO': {},
#  'CT': {},
#  'DE': {},
#  'FL': {},
#  'GA': {},
#  'HI': {},
#  'ID': {},
#  'IL': {},
#  'IN': {},
#  'IA': {},
#  'KS': {},
#  'KY': {},
#  'LA': {},
#  'ME': {},
#  'MD': {},
#  'MA': {},
#  'MI': {},
#  'MN': {},
#  'MS': {},
#  'MO': {},
#  'MT': {},
#  'NE': {},
#  'NV': {},
#  'NH': {},
#  'NJ': {},
#  'NM': {},
#  'NY': {},
#  'NC': {},
#  'ND': {},
#  'OH': {},
#  'OK': {},
#  'OR': {},
#  'PA': {},
#  'RI': {},
#  'SC': {},
#  'SD': {},
#  'TN': {},
#  'TX': {},
#  'UT': {},
#  'VT': {},
#  'VA': {},
#  'WA': {},
#  'WV': {},
#  'WI': {},
#  'WY': {}}

# %%
'''
Source: https://dataverse.harvard.edu/file.xhtml?fileId=4299753&version=6.0
'''

def political_parser():
    
    data = pd.read_csv('elections.csv')
    data.drop(['state','state_fips', 'state_cen', 'state_ic', 'office', 'candidate', 'writein', 'version', 'notes'], inplace=True, axis=1)
    data.dropna(inplace=True)
    data.to_csv('party_affiliation.csv', index=False)
    
    return data
    
############ Function Call ############
political_parser()
# Out:
#       year state_po              party_detailed  candidatevotes  totalvotes  \
# 0     1976       AL                    DEMOCRAT          659170     1182850
# 1     1976       AL                  REPUBLICAN          504070     1182850
# 2     1976       AL  AMERICAN INDEPENDENT PARTY            9198     1182850
# 3     1976       AL                 PROHIBITION            6669     1182850
# 4     1976       AL         COMMUNIST PARTY USE            1954     1182850
# ...    ...      ...                         ...             ...         ...
# 4278  2020       WI                 INDEPENDENT              52     3298041
# 4280  2020       WY                    DEMOCRAT           73491      278503
# 4281  2020       WY                  REPUBLICAN          193559      278503
# 4282  2020       WY                 LIBERTARIAN            5768      278503
# 4283  2020       WY                 INDEPENDENT            2208      278503
#
#      party_simplified
# 0            DEMOCRAT
# 1          REPUBLICAN
# 2               OTHER
# 3               OTHER
# 4               OTHER
# ...               ...
# 4278            OTHER
# 4280         DEMOCRAT
# 4281       REPUBLICAN
# 4282      LIBERTARIAN
# 4283            OTHER
#
# [3831 rows x 6 columns]

# %% [markdown]
# # Inconsistencies
# For each inconsistency (NaN, null, duplicate values, empty strings, etc.) you discover in your datasets, write at least 2 sentences stating the significance, how you identified it, and how you handled it.
#
# 1. null values - earthquake data (downloaded)
# Once the unused columns were removed, we used the 'dropna' function of pandas to automatically get rid of the rows with missing values. These missing values, like 'month' for some, are neccesary to match the data with the occurence of UFO sightings in the same month.
#
# 2. null values - drug crime data (api)
# We had to remove Florida from the list of states as it had null values for the overwhelming majority of years between '00 and '19. We identified this problem plotting the data on a choropleth map using plotly, seeing that it was skewing the rest of our data. Since the data was already compiled into a dictionary with states as the keys, all we had to do was '.pop()' Florida out of it.
#
# 3. weak data - ufo sightings (html)
# We wanted to make sure that we only had strong reports of ufo sightings to boost the credibility of our findings. To this end, we checked to see if the shape was 'unknown' and if the listed duration contained a concrete number. The shape verification was a simple string comparison and we verified the duration by checking to see if any of the chars were digits.
#
# 4. null values - ufo sightings (html)
# For this, we checked even the unused columns for null values to again boost the credibility of our findings. I thought the way we did this was kinda cool: we multiplied the boolean values of each attribute together with our 'weak data' boolean (#3) to check all of them at once. The weak data and null values were apparent by just glancing over the unaltered file.
#
# 5. extra rows - state abbreviations (extra no. 1)
# As the state abbreviations list would be used to iterate through both the api and the webpages we were pulling info from, we had to remove any extra abbreviations from the list. After finding that the data listed 56 'states' instead of 50, we just used '.remove()' to get rid of the extra 6.
